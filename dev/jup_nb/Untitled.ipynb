# %%
from depictio.api.v1.db import dashboards_collection
# Out:
# 2024-08-16 07:20:02,126 - depictio - INFO - config.py - <module> - line 9 - Using config file: depictio/api/v1/configs/config_backend_dockercompose.yaml
# 2024-08-16 07:20:02,133 - depictio - INFO - config.py - <module> - line 31 - API_BASE_URL: http://depictio_backend:8058
# 2024-08-16 07:20:02,133 - depictio - INFO - config.py - <module> - line 32 - MONGODB_URL: mongodb://mongo:27018/
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[1], line 4
#       2 os.environ["API_BASE_URL"] = "http://localhost:8058"
#       3 os.environ["MONGODB_URL"] = "mongodb://localhost:27018/"
# ----> 4 from depictio.api.v1.db import dashboards_collection
#
# File /app/depictio/api/v1/db.py:26
#      23 initialization_collection = db[settings.mongodb.collections.initialization_collection]
#      25 # Initialize admin user and token
# ---> 26 initialize_db()
#
# ...
