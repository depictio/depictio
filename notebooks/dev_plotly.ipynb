# %%
import pandas as pd
import dataprep.clean as clean
import plotly.express as px

def select_relevant_columns(df):
    # Find correlations between numeric columns
    correlations = df.corr().abs().unstack().sort_values(ascending=False)

    # Remove correlations of a column with itself
    correlations = correlations[correlations < 1]
    print(correlations)

    # Get the pair of columns with the highest correlation
    most_correlated_columns = correlations.index[0]
    print(most_correlated_columns)

    # Get the categorical column with the highest number of unique values
    categorical_columns = df.select_dtypes(include=['object', 'category']).columns
    most_unique_categorical = None
    max_unique_values = -1
    for column in categorical_columns:
        unique_values = df[column].nunique()
        if unique_values > max_unique_values:
            most_unique_categorical = column
            max_unique_values = unique_values

    return most_correlated_columns, most_unique_categorical

# %%
def auto_visualize(df, most_correlated_columns, most_unique_categorical):
    x, y = most_correlated_columns

    # Generate a scatter plot for the most correlated numerical columns
    scatter_fig = px.scatter(df, x=x, y=y, color=most_unique_categorical)

    return scatter_fig

# %%
url = 'https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv'
df = pd.read_csv(url)

# Clean and preprocess the DataFrame using DataPrep, if necessary

# %%
most_correlated_columns, most_unique_categorical = select_relevant_columns(df)
scatter_fig = auto_visualize(df, most_correlated_columns, most_unique_categorical)
scatter_fig.show()
# Out:
# /var/folders/3d/by4v0p913fsdr38hbw4s9tqc0000gp/T/ipykernel_16334/3073226569.py:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = df.corr().abs().unstack().sort_values(ascending=False)
# lifeExp    gdpPercap    0.583706
# gdpPercap  lifeExp      0.583706
# year       lifeExp      0.435611
# lifeExp    year         0.435611
# year       gdpPercap    0.227318
# gdpPercap  year         0.227318
# year       pop          0.082308
# pop        year         0.082308
#            lifeExp      0.064955
# lifeExp    pop          0.064955
# pop        gdpPercap    0.025600
# gdpPercap  pop          0.025600
# dtype: float64
# ('lifeExp', 'gdpPercap')

# %%
import inspect

plotly_vizu_list = [px.scatter, px.line, px.bar, px.histogram, px.box]

plotly_vizu_dict = {}
for vizu_func in plotly_vizu_list:
    plotly_vizu_dict[vizu_func.__name__] = vizu_func


common_params = set.intersection(
    *[set(inspect.signature(func).parameters.keys()) for func in plotly_vizu_list]
)
common_param_names = [p for p in list(common_params)]
common_param_names.sort(
    key=lambda x: list(inspect.signature(plotly_vizu_list[0]).parameters).index(x)
)

specific_params = {}

for vizu_func in plotly_vizu_list:
    func_params = inspect.signature(vizu_func).parameters
    param_names = list(func_params.keys())

    common_params_tmp = (
        common_params.intersection(func_params.keys())
        if common_params
        else set(func_params.keys())
    )

    specific_params[vizu_func] = [p for p in param_names if p not in common_params_tmp]

print("Common parameters:", common_param_names)
for vizu_func, params in specific_params.items():
    print(f"Specific parameters for {vizu_func.__name__}: {params}")
# Out:
# Common parameters: ['data_frame', 'x', 'y', 'color', 'hover_name', 'hover_data', 'facet_row', 'facet_col', 'facet_col_wrap', 'facet_row_spacing', 'facet_col_spacing', 'animation_frame', 'animation_group', 'category_orders', 'labels', 'orientation', 'color_discrete_sequence', 'color_discrete_map', 'log_x', 'log_y', 'range_x', 'range_y', 'title', 'template', 'width', 'height']
# Specific parameters for scatter: ['symbol', 'size', 'custom_data', 'text', 'error_x', 'error_x_minus', 'error_y', 'error_y_minus', 'color_continuous_scale', 'range_color', 'color_continuous_midpoint', 'symbol_sequence', 'symbol_map', 'opacity', 'size_max', 'marginal_x', 'marginal_y', 'trendline', 'trendline_options', 'trendline_color_override', 'trendline_scope', 'render_mode']
# Specific parameters for line: ['line_group', 'line_dash', 'symbol', 'custom_data', 'text', 'error_x', 'error_x_minus', 'error_y', 'error_y_minus', 'line_dash_sequence', 'line_dash_map', 'symbol_sequence', 'symbol_map', 'markers', 'line_shape', 'render_mode']
# Specific parameters for bar: ['pattern_shape', 'custom_data', 'text', 'base', 'error_x', 'error_x_minus', 'error_y', 'error_y_minus', 'color_continuous_scale', 'pattern_shape_sequence', 'pattern_shape_map', 'range_color', 'color_continuous_midpoint', 'opacity', 'barmode', 'text_auto']
# Specific parameters for histogram: ['pattern_shape', 'pattern_shape_sequence', 'pattern_shape_map', 'marginal', 'opacity', 'barmode', 'barnorm', 'histnorm', 'histfunc', 'cumulative', 'nbins', 'text_auto']
# Specific parameters for box: ['custom_data', 'boxmode', 'points', 'notched']

# %%
inspect.signature(plotly_vizu_list[0]).parameters
# Out:
# mappingproxy({'data_frame': <Parameter "data_frame=None">,
#               'x': <Parameter "x=None">,
#               'y': <Parameter "y=None">,
#               'color': <Parameter "color=None">,
#               'symbol': <Parameter "symbol=None">,
#               'size': <Parameter "size=None">,
#               'hover_name': <Parameter "hover_name=None">,
#               'hover_data': <Parameter "hover_data=None">,
#               'custom_data': <Parameter "custom_data=None">,
#               'text': <Parameter "text=None">,
#               'facet_row': <Parameter "facet_row=None">,
#               'facet_col': <Parameter "facet_col=None">,
#               'facet_col_wrap': <Parameter "facet_col_wrap=0">,
#               'facet_row_spacing': <Parameter "facet_row_spacing=None">,
#               'facet_col_spacing': <Parameter "facet_col_spacing=None">,
#               'error_x': <Parameter "error_x=None">,
#               'error_x_minus': <Parameter "error_x_minus=None">,
#               'error_y': <Parameter "error_y=None">,
#               'error_y_minus': <Parameter "error_y_minus=None">,
#               'animation_frame': <Parameter "animation_frame=None">,
#               'animation_group': <Parameter "animation_group=None">,
#               'category_orders': <Parameter "category_orders=None">,
#               'labels': <Parameter "labels=None">,
#               'orientation': <Parameter "orientation=None">,
#               'color_discrete_sequence': <Parameter "color_discrete_sequence=None">,
#               'color_discrete_map': <Parameter "color_discrete_map=None">,
#               'color_continuous_scale': <Parameter "color_continuous_scale=None">,
#               'range_color': <Parameter "range_color=None">,
#               'color_continuous_midpoint': <Parameter "color_continuous_midpoint=None">,
#               'symbol_sequence': <Parameter "symbol_sequence=None">,
#               'symbol_map': <Parameter "symbol_map=None">,
#               'opacity': <Parameter "opacity=None">,
#               'size_max': <Parameter "size_max=None">,
#               'marginal_x': <Parameter "marginal_x=None">,
#               'marginal_y': <Parameter "marginal_y=None">,
#               'trendline': <Parameter "trendline=None">,
#               'trendline_options': <Parameter "trendline_options=None">,
#               'trendline_color_override': <Parameter "trendline_color_override=None">,
#               'trendline_scope': <Parameter "trendline_scope='trace'">,
#               'log_x': <Parameter "log_x=False">,
#               'log_y': <Parameter "log_y=False">,
#               'range_x': <Parameter "range_x=None">,
#               'range_y': <Parameter "range_y=None">,
#               'render_mode': <Parameter "render_mode='auto'">,
#               'title': <Parameter "title=None">,
#               'template': <Parameter "template=None">,
#               'width': <Parameter "width=None">,
#               'height': <Parameter "height=None">})

# %%
import plotly.express as px
import inspect

sig = inspect.signature(px.scatter)
default_color = sig.parameters['color'].default
sig.parameters['color'].annotation.__values__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 6
#       4 sig = inspect.signature(px.scatter)
#       5 default_color = sig.parameters['color'].default
# ----> 6 sig.parameters['color'].annotation.__values__
#
# AttributeError: type object '_empty' has no attribute '__values__'

# %%
import plotly.express as px
import inspect
import re

plotly_vizu_list = [px.scatter, px.line, px.bar, px.histogram, px.box]

param_info = {}

for func in plotly_vizu_list:
    param_info[func.__name__] = {}
    docstring = func.__doc__
    print(docstring)
    # print(func.__name__, func.__doc__)
    if not docstring:
        continue

    first_match = False
    for j, line in enumerate(docstring.split("\n")):
        match = re.search(r"\s*([^\s]+):\s*(.+)", line)
        if match:
            param_name, param_desc = match.groups()
            if param_name not in ["'", "Optional"]:
                first_match = True
                param_info[func.__name__][param_name] = {
                    "description": param_desc.strip(),
                    "type": None,
                    # "options": None,
                }
        elif not match and first_match is True:
            print(j, line)

            # print(param_info)

            # signature = inspect.signature(func)
            # param = signature.parameters.get(param_name)
            # if param:
            #     if param.default is not inspect.Parameter.empty:
            #         param_info[func.__name__][param_name]["default"] = param.default

            #     if param.annotation is not inspect.Parameter.empty:
            #         if hasattr(param.annotation, "__args__"):
            #             if param.annotation.__args__[0] is not inspect.Parameter.empty:
            #                 param_info[func.__name__][param_name]["options"] = param.annotation.__args__[0]
            #         elif param.annotation is not None:
            #             param_info[func.__name__][param_name]["options"] = param.annotation

from pprint import pprint
# pprint(param_info)
# Out:
#     In a scatter plot, each row of `data_frame` is represented by a symbol
#     mark in 2D space.
#
# Parameters
# ----------
# data_frame: DataFrame or array-like or dict
#     This argument needs to be passed for column names (and not keyword
#     names) to be used. Array-like and dict are transformed internally to a
#     pandas DataFrame. Optional: if missing, a DataFrame gets constructed
#     under the hood using the other arguments.
# x: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the x axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# y: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the y axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# color: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign color to marks.
# symbol: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign symbols to marks.
# size: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign mark sizes.
# hover_name: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like appear in bold
#     in the hover tooltip.
# hover_data: str, or list of str or int, or Series or array-like, or dict
#     Either a name or list of names of columns in `data_frame`, or pandas
#     Series, or array_like objects or a dict with column names as keys, with
#     values True (for default formatting) False (in order to remove this
#     column from hover information), or a formatting string, for example
#     ':.3f' or '|%a' or list-like data to appear in the hover tooltip or
#     tuples with a bool or formatting string as first element, and list-like
#     data to appear in hover as second element Values from these columns
#     appear as extra data in the hover tooltip.
# custom_data: str, or list of str or int, or Series or array-like
#     Either name or list of names of columns in `data_frame`, or pandas
#     Series, or array_like objects Values from these columns are extra data,
#     to be used in widgets or Dash callbacks for example. This data is not
#     user-visible but is included in events emitted by the figure (lasso
#     selection etc.)
# text: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like appear in the
#     figure as text labels.
# facet_row: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to facetted subplots in the vertical direction.
# facet_col: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to facetted subplots in the horizontal direction.
# facet_col_wrap: int
#     Maximum number of facet columns. Wraps the column variable at this
#     width, so that the column facets span multiple rows. Ignored if 0, and
#     forced to 0 if `facet_row` or a `marginal` is set.
# facet_row_spacing: float between 0 and 1
#     Spacing between facet rows, in paper units. Default is 0.03 or 0.0.7
#     when facet_col_wrap is used.
# facet_col_spacing: float between 0 and 1
#     Spacing between facet columns, in paper units Default is 0.02.
# error_x: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size x-axis error bars. If `error_x_minus` is `None`, error bars will
#     be symmetrical, otherwise `error_x` is used for the positive direction
#     only.
# error_x_minus: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size x-axis error bars in the negative direction. Ignored if `error_x`
#     is `None`.
# error_y: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size y-axis error bars. If `error_y_minus` is `None`, error bars will
#     be symmetrical, otherwise `error_y` is used for the positive direction
#     only.
# error_y_minus: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size y-axis error bars in the negative direction. Ignored if `error_y`
#     is `None`.
# animation_frame: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to animation frames.
# animation_group: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     provide object-constancy across animation frames: rows with matching
#     `animation_group`s will be treated as if they describe the same object
#     in each frame.
# category_orders: dict with str keys and list of str values (default `{}`)
#     By default, in Python 3.6+, the order of categorical values in axes,
#     legends and facets depends on the order in which these values are first
#     encountered in `data_frame` (and no order is guaranteed by default in
#     Python below 3.6). This parameter is used to force a specific ordering
#     of values per column. The keys of this dict should correspond to column
#     names, and the values should be lists of strings corresponding to the
#     specific display order desired.
# labels: dict with str keys and str values (default `{}`)
#     By default, column names are used in the figure for axis titles, legend
#     entries and hovers. This parameter allows this to be overridden. The
#     keys of this dict should correspond to column names, and the values
#     should correspond to the desired label to be displayed.
# orientation: str, one of `'h'` for horizontal or `'v'` for vertical.
#     (default `'v'` if `x` and `y` are provided and both continous or both
#     categorical,  otherwise `'v'`(`'h'`) if `x`(`y`) is categorical and
#     `y`(`x`) is continuous,  otherwise `'v'`(`'h'`) if only `x`(`y`) is
#     provided)
# color_discrete_sequence: list of str
#     Strings should define valid CSS-colors. When `color` is set and the
#     values in the corresponding column are not numeric, values in that
#     column are assigned colors by cycling through `color_discrete_sequence`
#     in the order described in `category_orders`, unless the value of
#     `color` is a key in `color_discrete_map`. Various useful color
#     sequences are available in the `plotly.express.colors` submodules,
#     specifically `plotly.express.colors.qualitative`.
# color_discrete_map: dict with str keys and str values (default `{}`)
#     String values should define valid CSS-colors Used to override
#     `color_discrete_sequence` to assign a specific colors to marks
#     corresponding with specific values. Keys in `color_discrete_map` should
#     be values in the column denoted by `color`. Alternatively, if the
#     values of `color` are valid colors, the string `'identity'` may be
#     passed to cause them to be used directly.
# color_continuous_scale: list of str
#     Strings should define valid CSS-colors This list is used to build a
#     continuous color scale when the column denoted by `color` contains
#     numeric data. Various useful color scales are available in the
#     `plotly.express.colors` submodules, specifically
#     `plotly.express.colors.sequential`, `plotly.express.colors.diverging`
#     and `plotly.express.colors.cyclical`.
# range_color: list of two numbers
#     If provided, overrides auto-scaling on the continuous color scale.
# color_continuous_midpoint: number (default `None`)
#     If set, computes the bounds of the continuous color scale to have the
#     desired midpoint. Setting this value is recommended when using
#     `plotly.express.colors.diverging` color scales as the inputs to
#     `color_continuous_scale`.
# symbol_sequence: list of str
#     Strings should define valid plotly.js symbols. When `symbol` is set,
#     values in that column are assigned symbols by cycling through
#     `symbol_sequence` in the order described in `category_orders`, unless
#     the value of `symbol` is a key in `symbol_map`.
# symbol_map: dict with str keys and str values (default `{}`)
#     String values should define plotly.js symbols Used to override
#     `symbol_sequence` to assign a specific symbols to marks corresponding
#     with specific values. Keys in `symbol_map` should be values in the
#     column denoted by `symbol`. Alternatively, if the values of `symbol`
#     are valid symbol names, the string `'identity'` may be passed to cause
#     them to be used directly.
# opacity: float
#     Value between 0 and 1. Sets the opacity for markers.
# size_max: int (default `20`)
#     Set the maximum mark size when using `size`.
# marginal_x: str
#     One of `'rug'`, `'box'`, `'violin'`, or `'histogram'`. If set, a
#     horizontal subplot is drawn above the main plot, visualizing the
#     x-distribution.
# marginal_y: str
#     One of `'rug'`, `'box'`, `'violin'`, or `'histogram'`. If set, a
#     vertical subplot is drawn to the right of the main plot, visualizing
#     the y-distribution.
# trendline: str
#     One of `'ols'`, `'lowess'`, `'rolling'`, `'expanding'` or `'ewm'`. If
#     `'ols'`, an Ordinary Least Squares regression line will be drawn for
#     each discrete-color/symbol group. If `'lowess`', a Locally Weighted
#     Scatterplot Smoothing line will be drawn for each discrete-color/symbol
#     group. If `'rolling`', a Rolling (e.g. rolling average, rolling median)
#     line will be drawn for each discrete-color/symbol group. If
#     `'expanding`', an Expanding (e.g. expanding average, expanding sum)
#     line will be drawn for each discrete-color/symbol group. If `'ewm`', an
#     Exponentially Weighted Moment (e.g. exponentially-weighted moving
#     average) line will be drawn for each discrete-color/symbol group. See
#     the docstrings for the functions in
#     `plotly.express.trendline_functions` for more details on these
#     functions and how to configure them with the `trendline_options`
#     argument.
# trendline_options: dict
#     Options passed as the first argument to the function from
#     `plotly.express.trendline_functions`  named in the `trendline`
#     argument.
# trendline_color_override: str
#     Valid CSS color. If provided, and if `trendline` is set, all trendlines
#     will be drawn in this color rather than in the same color as the traces
#     from which they draw their inputs.
# trendline_scope: str (one of `'trace'` or `'overall'`, default `'trace'`)
#     If `'trace'`, then one trendline is drawn per trace (i.e. per color,
#     symbol, facet, animation frame etc) and if `'overall'` then one
#     trendline is computed for the entire dataset, and replicated across all
#     facets.
# log_x: boolean (default `False`)
#     If `True`, the x-axis is log-scaled in cartesian coordinates.
# log_y: boolean (default `False`)
#     If `True`, the y-axis is log-scaled in cartesian coordinates.
# range_x: list of two numbers
#     If provided, overrides auto-scaling on the x-axis in cartesian
#     coordinates.
# range_y: list of two numbers
#     If provided, overrides auto-scaling on the y-axis in cartesian
#     coordinates.
# render_mode: str
#     One of `'auto'`, `'svg'` or `'webgl'`, default `'auto'` Controls the
#     browser API used to draw marks. `'svg`' is appropriate for figures of
#     less than 1000 data points, and will allow for fully-vectorized output.
#     `'webgl'` is likely necessary for acceptable performance above 1000
#     points but rasterizes part of the output.  `'auto'` uses heuristics to
#     choose the mode.
# title: str
#     The figure title.
# template: str or dict or plotly.graph_objects.layout.Template instance
#     The figure template name (must be a key in plotly.io.templates) or
#     definition.
# width: int (default `None`)
#     The figure width in pixels.
# height: int (default `None`)
#     The figure height in pixels.
#
# Returns
# -------
#     plotly.graph_objects.Figure
# 7     This argument needs to be passed for column names (and not keyword
# 8     names) to be used. Array-like and dict are transformed internally to a
# 10     under the hood using the other arguments.
# 12     Either a name of a column in `data_frame`, or a pandas Series or
# 13     array_like object. Values from this column or array_like are used to
# 14     position marks along the x axis in cartesian coordinates. Either `x` or
# 15     `y` can optionally be a list of column references or array_likes,  in
# 16     which case the data will be treated as if it were 'wide' rather than
# 17     'long'.
# 19     Either a name of a column in `data_frame`, or a pandas Series or
# 20     array_like object. Values from this column or array_like are used to
# 21     position marks along the y axis in cartesian coordinates. Either `x` or
# 22     `y` can optionally be a list of column references or array_likes,  in
# 23     which case the data will be treated as if it were 'wide' rather than
# 24     'long'.
# 26     Either a name of a column in `data_frame`, or a pandas Series or
# 27     array_like object. Values from this column or array_like are used to
# 28     assign color to marks.
# 30     Either a name of a column in `data_frame`, or a pandas Series or
# 31     array_like object. Values from this column or array_like are used to
# 32     assign symbols to marks.
# 34     Either a name of a column in `data_frame`, or a pandas Series or
# 35     array_like object. Values from this column or array_like are used to
# 36     assign mark sizes.
# 38     Either a name of a column in `data_frame`, or a pandas Series or
# 39     array_like object. Values from this column or array_like appear in bold
# 40     in the hover tooltip.
# 42     Either a name or list of names of columns in `data_frame`, or pandas
# 43     Series, or array_like objects or a dict with column names as keys, with
# 44     values True (for default formatting) False (in order to remove this
# 45     column from hover information), or a formatting string, for example
# 47     tuples with a bool or formatting string as first element, and list-like
# 48     data to appear in hover as second element Values from these columns
# 49     appear as extra data in the hover tooltip.
# 51     Either name or list of names of columns in `data_frame`, or pandas
# 52     Series, or array_like objects Values from these columns are extra data,
# 53     to be used in widgets or Dash callbacks for example. This data is not
# 54     user-visible but is included in events emitted by the figure (lasso
# 55     selection etc.)
# 57     Either a name of a column in `data_frame`, or a pandas Series or
# 58     array_like object. Values from this column or array_like appear in the
# 59     figure as text labels.
# 61     Either a name of a column in `data_frame`, or a pandas Series or
# 62     array_like object. Values from this column or array_like are used to
# 63     assign marks to facetted subplots in the vertical direction.
# 65     Either a name of a column in `data_frame`, or a pandas Series or
# 66     array_like object. Values from this column or array_like are used to
# 67     assign marks to facetted subplots in the horizontal direction.
# 69     Maximum number of facet columns. Wraps the column variable at this
# 70     width, so that the column facets span multiple rows. Ignored if 0, and
# 71     forced to 0 if `facet_row` or a `marginal` is set.
# 73     Spacing between facet rows, in paper units. Default is 0.03 or 0.0.7
# 74     when facet_col_wrap is used.
# 76     Spacing between facet columns, in paper units Default is 0.02.
# 78     Either a name of a column in `data_frame`, or a pandas Series or
# 79     array_like object. Values from this column or array_like are used to
# 80     size x-axis error bars. If `error_x_minus` is `None`, error bars will
# 81     be symmetrical, otherwise `error_x` is used for the positive direction
# 82     only.
# 84     Either a name of a column in `data_frame`, or a pandas Series or
# 85     array_like object. Values from this column or array_like are used to
# 86     size x-axis error bars in the negative direction. Ignored if `error_x`
# 87     is `None`.
# 89     Either a name of a column in `data_frame`, or a pandas Series or
# 90     array_like object. Values from this column or array_like are used to
# 91     size y-axis error bars. If `error_y_minus` is `None`, error bars will
# 92     be symmetrical, otherwise `error_y` is used for the positive direction
# 93     only.
# 95     Either a name of a column in `data_frame`, or a pandas Series or
# 96     array_like object. Values from this column or array_like are used to
# 97     size y-axis error bars in the negative direction. Ignored if `error_y`
# 98     is `None`.
# 100     Either a name of a column in `data_frame`, or a pandas Series or
# 101     array_like object. Values from this column or array_like are used to
# 102     assign marks to animation frames.
# 104     Either a name of a column in `data_frame`, or a pandas Series or
# 105     array_like object. Values from this column or array_like are used to
# 107     `animation_group`s will be treated as if they describe the same object
# 108     in each frame.
# 110     By default, in Python 3.6+, the order of categorical values in axes,
# 111     legends and facets depends on the order in which these values are first
# 112     encountered in `data_frame` (and no order is guaranteed by default in
# 113     Python below 3.6). This parameter is used to force a specific ordering
# 114     of values per column. The keys of this dict should correspond to column
# 115     names, and the values should be lists of strings corresponding to the
# 116     specific display order desired.
# 118     By default, column names are used in the figure for axis titles, legend
# 119     entries and hovers. This parameter allows this to be overridden. The
# 120     keys of this dict should correspond to column names, and the values
# 121     should correspond to the desired label to be displayed.
# 123     (default `'v'` if `x` and `y` are provided and both continous or both
# 124     categorical,  otherwise `'v'`(`'h'`) if `x`(`y`) is categorical and
# 125     `y`(`x`) is continuous,  otherwise `'v'`(`'h'`) if only `x`(`y`) is
# 126     provided)
# 128     Strings should define valid CSS-colors. When `color` is set and the
# 129     values in the corresponding column are not numeric, values in that
# 130     column are assigned colors by cycling through `color_discrete_sequence`
# 131     in the order described in `category_orders`, unless the value of
# 132     `color` is a key in `color_discrete_map`. Various useful color
# 133     sequences are available in the `plotly.express.colors` submodules,
# 134     specifically `plotly.express.colors.qualitative`.
# 136     String values should define valid CSS-colors Used to override
# 137     `color_discrete_sequence` to assign a specific colors to marks
# 138     corresponding with specific values. Keys in `color_discrete_map` should
# 139     be values in the column denoted by `color`. Alternatively, if the
# 140     values of `color` are valid colors, the string `'identity'` may be
# 141     passed to cause them to be used directly.
# 143     Strings should define valid CSS-colors This list is used to build a
# 144     continuous color scale when the column denoted by `color` contains
# 145     numeric data. Various useful color scales are available in the
# 146     `plotly.express.colors` submodules, specifically
# 147     `plotly.express.colors.sequential`, `plotly.express.colors.diverging`
# 148     and `plotly.express.colors.cyclical`.
# 150     If provided, overrides auto-scaling on the continuous color scale.
# 152     If set, computes the bounds of the continuous color scale to have the
# 153     desired midpoint. Setting this value is recommended when using
# 154     `plotly.express.colors.diverging` color scales as the inputs to
# 155     `color_continuous_scale`.
# 157     Strings should define valid plotly.js symbols. When `symbol` is set,
# 158     values in that column are assigned symbols by cycling through
# 159     `symbol_sequence` in the order described in `category_orders`, unless
# 160     the value of `symbol` is a key in `symbol_map`.
# 162     String values should define plotly.js symbols Used to override
# 163     `symbol_sequence` to assign a specific symbols to marks corresponding
# 164     with specific values. Keys in `symbol_map` should be values in the
# 165     column denoted by `symbol`. Alternatively, if the values of `symbol`
# 166     are valid symbol names, the string `'identity'` may be passed to cause
# 167     them to be used directly.
# 169     Value between 0 and 1. Sets the opacity for markers.
# 171     Set the maximum mark size when using `size`.
# 173     One of `'rug'`, `'box'`, `'violin'`, or `'histogram'`. If set, a
# 174     horizontal subplot is drawn above the main plot, visualizing the
# 175     x-distribution.
# 177     One of `'rug'`, `'box'`, `'violin'`, or `'histogram'`. If set, a
# 178     vertical subplot is drawn to the right of the main plot, visualizing
# 179     the y-distribution.
# 181     One of `'ols'`, `'lowess'`, `'rolling'`, `'expanding'` or `'ewm'`. If
# 182     `'ols'`, an Ordinary Least Squares regression line will be drawn for
# 183     each discrete-color/symbol group. If `'lowess`', a Locally Weighted
# 184     Scatterplot Smoothing line will be drawn for each discrete-color/symbol
# 185     group. If `'rolling`', a Rolling (e.g. rolling average, rolling median)
# 186     line will be drawn for each discrete-color/symbol group. If
# 187     `'expanding`', an Expanding (e.g. expanding average, expanding sum)
# 188     line will be drawn for each discrete-color/symbol group. If `'ewm`', an
# 189     Exponentially Weighted Moment (e.g. exponentially-weighted moving
# 190     average) line will be drawn for each discrete-color/symbol group. See
# 191     the docstrings for the functions in
# 192     `plotly.express.trendline_functions` for more details on these
# 193     functions and how to configure them with the `trendline_options`
# 194     argument.
# 196     Options passed as the first argument to the function from
# 197     `plotly.express.trendline_functions`  named in the `trendline`
# 198     argument.
# 200     Valid CSS color. If provided, and if `trendline` is set, all trendlines
# 201     will be drawn in this color rather than in the same color as the traces
# 202     from which they draw their inputs.
# 204     If `'trace'`, then one trendline is drawn per trace (i.e. per color,
# 205     symbol, facet, animation frame etc) and if `'overall'` then one
# 206     trendline is computed for the entire dataset, and replicated across all
# 207     facets.
# 209     If `True`, the x-axis is log-scaled in cartesian coordinates.
# 211     If `True`, the y-axis is log-scaled in cartesian coordinates.
# 213     If provided, overrides auto-scaling on the x-axis in cartesian
# 214     coordinates.
# 216     If provided, overrides auto-scaling on the y-axis in cartesian
# 217     coordinates.
# 219     One of `'auto'`, `'svg'` or `'webgl'`, default `'auto'` Controls the
# 220     browser API used to draw marks. `'svg`' is appropriate for figures of
# 221     less than 1000 data points, and will allow for fully-vectorized output.
# 222     `'webgl'` is likely necessary for acceptable performance above 1000
# 223     points but rasterizes part of the output.  `'auto'` uses heuristics to
# 224     choose the mode.
# 226     The figure title.
# 228     The figure template name (must be a key in plotly.io.templates) or
# 229     definition.
# 231     The figure width in pixels.
# 233     The figure height in pixels.
# 234
# 235 Returns
# 236 -------
# 237     plotly.graph_objects.Figure
#
#     In a 2D line plot, each row of `data_frame` is represented as vertex of
#     a polyline mark in 2D space.
#
# Parameters
# ----------
# data_frame: DataFrame or array-like or dict
#     This argument needs to be passed for column names (and not keyword
#     names) to be used. Array-like and dict are transformed internally to a
#     pandas DataFrame. Optional: if missing, a DataFrame gets constructed
#     under the hood using the other arguments.
# x: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the x axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# y: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the y axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# line_group: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     group rows of `data_frame` into lines.
# color: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign color to marks.
# line_dash: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign dash-patterns to lines.
# symbol: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign symbols to marks.
# hover_name: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like appear in bold
#     in the hover tooltip.
# hover_data: str, or list of str or int, or Series or array-like, or dict
#     Either a name or list of names of columns in `data_frame`, or pandas
#     Series, or array_like objects or a dict with column names as keys, with
#     values True (for default formatting) False (in order to remove this
#     column from hover information), or a formatting string, for example
#     ':.3f' or '|%a' or list-like data to appear in the hover tooltip or
#     tuples with a bool or formatting string as first element, and list-like
#     data to appear in hover as second element Values from these columns
#     appear as extra data in the hover tooltip.
# custom_data: str, or list of str or int, or Series or array-like
#     Either name or list of names of columns in `data_frame`, or pandas
#     Series, or array_like objects Values from these columns are extra data,
#     to be used in widgets or Dash callbacks for example. This data is not
#     user-visible but is included in events emitted by the figure (lasso
#     selection etc.)
# text: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like appear in the
#     figure as text labels.
# facet_row: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to facetted subplots in the vertical direction.
# facet_col: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to facetted subplots in the horizontal direction.
# facet_col_wrap: int
#     Maximum number of facet columns. Wraps the column variable at this
#     width, so that the column facets span multiple rows. Ignored if 0, and
#     forced to 0 if `facet_row` or a `marginal` is set.
# facet_row_spacing: float between 0 and 1
#     Spacing between facet rows, in paper units. Default is 0.03 or 0.0.7
#     when facet_col_wrap is used.
# facet_col_spacing: float between 0 and 1
#     Spacing between facet columns, in paper units Default is 0.02.
# error_x: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size x-axis error bars. If `error_x_minus` is `None`, error bars will
#     be symmetrical, otherwise `error_x` is used for the positive direction
#     only.
# error_x_minus: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size x-axis error bars in the negative direction. Ignored if `error_x`
#     is `None`.
# error_y: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size y-axis error bars. If `error_y_minus` is `None`, error bars will
#     be symmetrical, otherwise `error_y` is used for the positive direction
#     only.
# error_y_minus: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size y-axis error bars in the negative direction. Ignored if `error_y`
#     is `None`.
# animation_frame: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to animation frames.
# animation_group: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     provide object-constancy across animation frames: rows with matching
#     `animation_group`s will be treated as if they describe the same object
#     in each frame.
# category_orders: dict with str keys and list of str values (default `{}`)
#     By default, in Python 3.6+, the order of categorical values in axes,
#     legends and facets depends on the order in which these values are first
#     encountered in `data_frame` (and no order is guaranteed by default in
#     Python below 3.6). This parameter is used to force a specific ordering
#     of values per column. The keys of this dict should correspond to column
#     names, and the values should be lists of strings corresponding to the
#     specific display order desired.
# labels: dict with str keys and str values (default `{}`)
#     By default, column names are used in the figure for axis titles, legend
#     entries and hovers. This parameter allows this to be overridden. The
#     keys of this dict should correspond to column names, and the values
#     should correspond to the desired label to be displayed.
# orientation: str, one of `'h'` for horizontal or `'v'` for vertical.
#     (default `'v'` if `x` and `y` are provided and both continous or both
#     categorical,  otherwise `'v'`(`'h'`) if `x`(`y`) is categorical and
#     `y`(`x`) is continuous,  otherwise `'v'`(`'h'`) if only `x`(`y`) is
#     provided)
# color_discrete_sequence: list of str
#     Strings should define valid CSS-colors. When `color` is set and the
#     values in the corresponding column are not numeric, values in that
#     column are assigned colors by cycling through `color_discrete_sequence`
#     in the order described in `category_orders`, unless the value of
#     `color` is a key in `color_discrete_map`. Various useful color
#     sequences are available in the `plotly.express.colors` submodules,
#     specifically `plotly.express.colors.qualitative`.
# color_discrete_map: dict with str keys and str values (default `{}`)
#     String values should define valid CSS-colors Used to override
#     `color_discrete_sequence` to assign a specific colors to marks
#     corresponding with specific values. Keys in `color_discrete_map` should
#     be values in the column denoted by `color`. Alternatively, if the
#     values of `color` are valid colors, the string `'identity'` may be
#     passed to cause them to be used directly.
# line_dash_sequence: list of str
#     Strings should define valid plotly.js dash-patterns. When `line_dash`
#     is set, values in that column are assigned dash-patterns by cycling
#     through `line_dash_sequence` in the order described in
#     `category_orders`, unless the value of `line_dash` is a key in
#     `line_dash_map`.
# line_dash_map: dict with str keys and str values (default `{}`)
#     Strings values define plotly.js dash-patterns. Used to override
#     `line_dash_sequences` to assign a specific dash-patterns to lines
#     corresponding with specific values. Keys in `line_dash_map` should be
#     values in the column denoted by `line_dash`. Alternatively, if the
#     values of `line_dash` are valid line-dash names, the string
#     `'identity'` may be passed to cause them to be used directly.
# symbol_sequence: list of str
#     Strings should define valid plotly.js symbols. When `symbol` is set,
#     values in that column are assigned symbols by cycling through
#     `symbol_sequence` in the order described in `category_orders`, unless
#     the value of `symbol` is a key in `symbol_map`.
# symbol_map: dict with str keys and str values (default `{}`)
#     String values should define plotly.js symbols Used to override
#     `symbol_sequence` to assign a specific symbols to marks corresponding
#     with specific values. Keys in `symbol_map` should be values in the
#     column denoted by `symbol`. Alternatively, if the values of `symbol`
#     are valid symbol names, the string `'identity'` may be passed to cause
#     them to be used directly.
# markers: boolean (default `False`)
#     If `True`, markers are shown on lines.
# log_x: boolean (default `False`)
#     If `True`, the x-axis is log-scaled in cartesian coordinates.
# log_y: boolean (default `False`)
#     If `True`, the y-axis is log-scaled in cartesian coordinates.
# range_x: list of two numbers
#     If provided, overrides auto-scaling on the x-axis in cartesian
#     coordinates.
# range_y: list of two numbers
#     If provided, overrides auto-scaling on the y-axis in cartesian
#     coordinates.
# line_shape: str (default `'linear'`)
#     One of `'linear'` or `'spline'`.
# render_mode: str
#     One of `'auto'`, `'svg'` or `'webgl'`, default `'auto'` Controls the
#     browser API used to draw marks. `'svg`' is appropriate for figures of
#     less than 1000 data points, and will allow for fully-vectorized output.
#     `'webgl'` is likely necessary for acceptable performance above 1000
#     points but rasterizes part of the output.  `'auto'` uses heuristics to
#     choose the mode.
# title: str
#     The figure title.
# template: str or dict or plotly.graph_objects.layout.Template instance
#     The figure template name (must be a key in plotly.io.templates) or
#     definition.
# width: int (default `None`)
#     The figure width in pixels.
# height: int (default `None`)
#     The figure height in pixels.
#
# Returns
# -------
#     plotly.graph_objects.Figure
# 7     This argument needs to be passed for column names (and not keyword
# 8     names) to be used. Array-like and dict are transformed internally to a
# 10     under the hood using the other arguments.
# 12     Either a name of a column in `data_frame`, or a pandas Series or
# 13     array_like object. Values from this column or array_like are used to
# 14     position marks along the x axis in cartesian coordinates. Either `x` or
# 15     `y` can optionally be a list of column references or array_likes,  in
# 16     which case the data will be treated as if it were 'wide' rather than
# 17     'long'.
# 19     Either a name of a column in `data_frame`, or a pandas Series or
# 20     array_like object. Values from this column or array_like are used to
# 21     position marks along the y axis in cartesian coordinates. Either `x` or
# 22     `y` can optionally be a list of column references or array_likes,  in
# 23     which case the data will be treated as if it were 'wide' rather than
# 24     'long'.
# 26     Either a name of a column in `data_frame`, or a pandas Series or
# 27     array_like object. Values from this column or array_like are used to
# 28     group rows of `data_frame` into lines.
# 30     Either a name of a column in `data_frame`, or a pandas Series or
# 31     array_like object. Values from this column or array_like are used to
# 32     assign color to marks.
# 34     Either a name of a column in `data_frame`, or a pandas Series or
# 35     array_like object. Values from this column or array_like are used to
# 36     assign dash-patterns to lines.
# 38     Either a name of a column in `data_frame`, or a pandas Series or
# 39     array_like object. Values from this column or array_like are used to
# 40     assign symbols to marks.
# 42     Either a name of a column in `data_frame`, or a pandas Series or
# 43     array_like object. Values from this column or array_like appear in bold
# 44     in the hover tooltip.
# 46     Either a name or list of names of columns in `data_frame`, or pandas
# 47     Series, or array_like objects or a dict with column names as keys, with
# 48     values True (for default formatting) False (in order to remove this
# 49     column from hover information), or a formatting string, for example
# 51     tuples with a bool or formatting string as first element, and list-like
# 52     data to appear in hover as second element Values from these columns
# 53     appear as extra data in the hover tooltip.
# 55     Either name or list of names of columns in `data_frame`, or pandas
# 56     Series, or array_like objects Values from these columns are extra data,
# 57     to be used in widgets or Dash callbacks for example. This data is not
# 58     user-visible but is included in events emitted by the figure (lasso
# 59     selection etc.)
# 61     Either a name of a column in `data_frame`, or a pandas Series or
# 62     array_like object. Values from this column or array_like appear in the
# 63     figure as text labels.
# 65     Either a name of a column in `data_frame`, or a pandas Series or
# 66     array_like object. Values from this column or array_like are used to
# 67     assign marks to facetted subplots in the vertical direction.
# 69     Either a name of a column in `data_frame`, or a pandas Series or
# 70     array_like object. Values from this column or array_like are used to
# 71     assign marks to facetted subplots in the horizontal direction.
# 73     Maximum number of facet columns. Wraps the column variable at this
# 74     width, so that the column facets span multiple rows. Ignored if 0, and
# 75     forced to 0 if `facet_row` or a `marginal` is set.
# 77     Spacing between facet rows, in paper units. Default is 0.03 or 0.0.7
# 78     when facet_col_wrap is used.
# 80     Spacing between facet columns, in paper units Default is 0.02.
# 82     Either a name of a column in `data_frame`, or a pandas Series or
# 83     array_like object. Values from this column or array_like are used to
# 84     size x-axis error bars. If `error_x_minus` is `None`, error bars will
# 85     be symmetrical, otherwise `error_x` is used for the positive direction
# 86     only.
# 88     Either a name of a column in `data_frame`, or a pandas Series or
# 89     array_like object. Values from this column or array_like are used to
# 90     size x-axis error bars in the negative direction. Ignored if `error_x`
# 91     is `None`.
# 93     Either a name of a column in `data_frame`, or a pandas Series or
# 94     array_like object. Values from this column or array_like are used to
# 95     size y-axis error bars. If `error_y_minus` is `None`, error bars will
# 96     be symmetrical, otherwise `error_y` is used for the positive direction
# 97     only.
# 99     Either a name of a column in `data_frame`, or a pandas Series or
# 100     array_like object. Values from this column or array_like are used to
# 101     size y-axis error bars in the negative direction. Ignored if `error_y`
# 102     is `None`.
# 104     Either a name of a column in `data_frame`, or a pandas Series or
# 105     array_like object. Values from this column or array_like are used to
# 106     assign marks to animation frames.
# 108     Either a name of a column in `data_frame`, or a pandas Series or
# 109     array_like object. Values from this column or array_like are used to
# 111     `animation_group`s will be treated as if they describe the same object
# 112     in each frame.
# 114     By default, in Python 3.6+, the order of categorical values in axes,
# 115     legends and facets depends on the order in which these values are first
# 116     encountered in `data_frame` (and no order is guaranteed by default in
# 117     Python below 3.6). This parameter is used to force a specific ordering
# 118     of values per column. The keys of this dict should correspond to column
# 119     names, and the values should be lists of strings corresponding to the
# 120     specific display order desired.
# 122     By default, column names are used in the figure for axis titles, legend
# 123     entries and hovers. This parameter allows this to be overridden. The
# 124     keys of this dict should correspond to column names, and the values
# 125     should correspond to the desired label to be displayed.
# 127     (default `'v'` if `x` and `y` are provided and both continous or both
# 128     categorical,  otherwise `'v'`(`'h'`) if `x`(`y`) is categorical and
# 129     `y`(`x`) is continuous,  otherwise `'v'`(`'h'`) if only `x`(`y`) is
# 130     provided)
# 132     Strings should define valid CSS-colors. When `color` is set and the
# 133     values in the corresponding column are not numeric, values in that
# 134     column are assigned colors by cycling through `color_discrete_sequence`
# 135     in the order described in `category_orders`, unless the value of
# 136     `color` is a key in `color_discrete_map`. Various useful color
# 137     sequences are available in the `plotly.express.colors` submodules,
# 138     specifically `plotly.express.colors.qualitative`.
# 140     String values should define valid CSS-colors Used to override
# 141     `color_discrete_sequence` to assign a specific colors to marks
# 142     corresponding with specific values. Keys in `color_discrete_map` should
# 143     be values in the column denoted by `color`. Alternatively, if the
# 144     values of `color` are valid colors, the string `'identity'` may be
# 145     passed to cause them to be used directly.
# 147     Strings should define valid plotly.js dash-patterns. When `line_dash`
# 148     is set, values in that column are assigned dash-patterns by cycling
# 149     through `line_dash_sequence` in the order described in
# 150     `category_orders`, unless the value of `line_dash` is a key in
# 151     `line_dash_map`.
# 153     Strings values define plotly.js dash-patterns. Used to override
# 154     `line_dash_sequences` to assign a specific dash-patterns to lines
# 155     corresponding with specific values. Keys in `line_dash_map` should be
# 156     values in the column denoted by `line_dash`. Alternatively, if the
# 157     values of `line_dash` are valid line-dash names, the string
# 158     `'identity'` may be passed to cause them to be used directly.
# 160     Strings should define valid plotly.js symbols. When `symbol` is set,
# 161     values in that column are assigned symbols by cycling through
# 162     `symbol_sequence` in the order described in `category_orders`, unless
# 163     the value of `symbol` is a key in `symbol_map`.
# 165     String values should define plotly.js symbols Used to override
# 166     `symbol_sequence` to assign a specific symbols to marks corresponding
# 167     with specific values. Keys in `symbol_map` should be values in the
# 168     column denoted by `symbol`. Alternatively, if the values of `symbol`
# 169     are valid symbol names, the string `'identity'` may be passed to cause
# 170     them to be used directly.
# 172     If `True`, markers are shown on lines.
# 174     If `True`, the x-axis is log-scaled in cartesian coordinates.
# 176     If `True`, the y-axis is log-scaled in cartesian coordinates.
# 178     If provided, overrides auto-scaling on the x-axis in cartesian
# 179     coordinates.
# 181     If provided, overrides auto-scaling on the y-axis in cartesian
# 182     coordinates.
# 184     One of `'linear'` or `'spline'`.
# 186     One of `'auto'`, `'svg'` or `'webgl'`, default `'auto'` Controls the
# 187     browser API used to draw marks. `'svg`' is appropriate for figures of
# 188     less than 1000 data points, and will allow for fully-vectorized output.
# 189     `'webgl'` is likely necessary for acceptable performance above 1000
# 190     points but rasterizes part of the output.  `'auto'` uses heuristics to
# 191     choose the mode.
# 193     The figure title.
# 195     The figure template name (must be a key in plotly.io.templates) or
# 196     definition.
# 198     The figure width in pixels.
# 200     The figure height in pixels.
# 201
# 202 Returns
# 203 -------
# 204     plotly.graph_objects.Figure
#
#     In a bar plot, each row of `data_frame` is represented as a rectangular
#     mark.
#
# Parameters
# ----------
# data_frame: DataFrame or array-like or dict
#     This argument needs to be passed for column names (and not keyword
#     names) to be used. Array-like and dict are transformed internally to a
#     pandas DataFrame. Optional: if missing, a DataFrame gets constructed
#     under the hood using the other arguments.
# x: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the x axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# y: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the y axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# color: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign color to marks.
# pattern_shape: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign pattern shapes to marks.
# facet_row: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
# ...
# 163     `histnorm`). The arguments to this function are the values of `y`(`x`)
# 164     if `orientation` is `'v'`(`'h'`).
# 166     If `True`, histogram values are cumulative.
# 168     Positive integer. Sets the number of bins.
# 170     If `True` or a string, the x or y or z values will be displayed as
# 171     text, depending on the orientation A string like `'.2f'` will be
# 172     interpreted as a `texttemplate` numeric formatting directive.
# 174     The figure title.
# 176     The figure template name (must be a key in plotly.io.templates) or
# 177     definition.
# 179     The figure width in pixels.
# 181     The figure height in pixels.
# 182
# 183 Returns
# 184 -------
# 185     plotly.graph_objects.Figure
#
#     In a box plot, rows of `data_frame` are grouped together into a
#     box-and-whisker mark to visualize their distribution.
#
#     Each box spans from quartile 1 (Q1) to quartile 3 (Q3). The second
#     quartile (Q2) is marked by a line inside the box. By default, the
#     whiskers correspond to the box' edges +/- 1.5 times the interquartile
#     range (IQR: Q3-Q1), see "points" for other options.
#
# Parameters
# ----------
# data_frame: DataFrame or array-like or dict
#     This argument needs to be passed for column names (and not keyword
#     names) to be used. Array-like and dict are transformed internally to a
#     pandas DataFrame. Optional: if missing, a DataFrame gets constructed
#     under the hood using the other arguments.
# x: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the x axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# y: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the y axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# color: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign color to marks.
# facet_row: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to facetted subplots in the vertical direction.
# facet_col: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to facetted subplots in the horizontal direction.
# facet_col_wrap: int
#     Maximum number of facet columns. Wraps the column variable at this
#     width, so that the column facets span multiple rows. Ignored if 0, and
#     forced to 0 if `facet_row` or a `marginal` is set.
# facet_row_spacing: float between 0 and 1
#     Spacing between facet rows, in paper units. Default is 0.03 or 0.0.7
#     when facet_col_wrap is used.
# facet_col_spacing: float between 0 and 1
#     Spacing between facet columns, in paper units Default is 0.02.
# hover_name: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like appear in bold
#     in the hover tooltip.
# hover_data: str, or list of str or int, or Series or array-like, or dict
#     Either a name or list of names of columns in `data_frame`, or pandas
#     Series, or array_like objects or a dict with column names as keys, with
#     values True (for default formatting) False (in order to remove this
#     column from hover information), or a formatting string, for example
#     ':.3f' or '|%a' or list-like data to appear in the hover tooltip or
#     tuples with a bool or formatting string as first element, and list-like
#     data to appear in hover as second element Values from these columns
#     appear as extra data in the hover tooltip.
# custom_data: str, or list of str or int, or Series or array-like
#     Either name or list of names of columns in `data_frame`, or pandas
#     Series, or array_like objects Values from these columns are extra data,
#     to be used in widgets or Dash callbacks for example. This data is not
#     user-visible but is included in events emitted by the figure (lasso
#     selection etc.)
# animation_frame: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to animation frames.
# animation_group: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     provide object-constancy across animation frames: rows with matching
#     `animation_group`s will be treated as if they describe the same object
#     in each frame.
# category_orders: dict with str keys and list of str values (default `{}`)
#     By default, in Python 3.6+, the order of categorical values in axes,
#     legends and facets depends on the order in which these values are first
#     encountered in `data_frame` (and no order is guaranteed by default in
#     Python below 3.6). This parameter is used to force a specific ordering
#     of values per column. The keys of this dict should correspond to column
#     names, and the values should be lists of strings corresponding to the
#     specific display order desired.
# labels: dict with str keys and str values (default `{}`)
#     By default, column names are used in the figure for axis titles, legend
#     entries and hovers. This parameter allows this to be overridden. The
#     keys of this dict should correspond to column names, and the values
#     should correspond to the desired label to be displayed.
# color_discrete_sequence: list of str
#     Strings should define valid CSS-colors. When `color` is set and the
#     values in the corresponding column are not numeric, values in that
#     column are assigned colors by cycling through `color_discrete_sequence`
#     in the order described in `category_orders`, unless the value of
#     `color` is a key in `color_discrete_map`. Various useful color
#     sequences are available in the `plotly.express.colors` submodules,
#     specifically `plotly.express.colors.qualitative`.
# color_discrete_map: dict with str keys and str values (default `{}`)
#     String values should define valid CSS-colors Used to override
#     `color_discrete_sequence` to assign a specific colors to marks
#     corresponding with specific values. Keys in `color_discrete_map` should
#     be values in the column denoted by `color`. Alternatively, if the
#     values of `color` are valid colors, the string `'identity'` may be
#     passed to cause them to be used directly.
# orientation: str, one of `'h'` for horizontal or `'v'` for vertical.
#     (default `'v'` if `x` and `y` are provided and both continous or both
#     categorical,  otherwise `'v'`(`'h'`) if `x`(`y`) is categorical and
#     `y`(`x`) is continuous,  otherwise `'v'`(`'h'`) if only `x`(`y`) is
#     provided)
# boxmode: str (default `'group'`)
#     One of `'group'` or `'overlay'` In `'overlay'` mode, boxes are on drawn
#     top of one another. In `'group'` mode, boxes are placed beside each
#     other.
# log_x: boolean (default `False`)
#     If `True`, the x-axis is log-scaled in cartesian coordinates.
# log_y: boolean (default `False`)
#     If `True`, the y-axis is log-scaled in cartesian coordinates.
# range_x: list of two numbers
#     If provided, overrides auto-scaling on the x-axis in cartesian
#     coordinates.
# range_y: list of two numbers
#     If provided, overrides auto-scaling on the y-axis in cartesian
#     coordinates.
# points: str or boolean (default `'outliers'`)
#     One of `'outliers'`, `'suspectedoutliers'`, `'all'`, or `False`. If
#     `'outliers'`, only the sample points lying outside the whiskers are
#     shown. If `'suspectedoutliers'`, all outlier points are shown and those
#     less than 4*Q1-3*Q3 or greater than 4*Q3-3*Q1 are highlighted with the
#     marker's `'outliercolor'`. If `'outliers'`, only the sample points
#     lying outside the whiskers are shown. If `'all'`, all sample points are
#     shown. If `False`, no sample points are shown and the whiskers extend
#     to the full range of the sample.
# notched: boolean (default `False`)
#     If `True`, boxes are drawn with notches.
# title: str
#     The figure title.
# template: str or dict or plotly.graph_objects.layout.Template instance
#     The figure template name (must be a key in plotly.io.templates) or
#     definition.
# width: int (default `None`)
#     The figure width in pixels.
# height: int (default `None`)
#     The figure height in pixels.
#
# Returns
# -------
#     plotly.graph_objects.Figure
# 8
# 9 Parameters
# 10 ----------
# 12     This argument needs to be passed for column names (and not keyword
# 13     names) to be used. Array-like and dict are transformed internally to a
# 15     under the hood using the other arguments.
# 17     Either a name of a column in `data_frame`, or a pandas Series or
# 18     array_like object. Values from this column or array_like are used to
# 19     position marks along the x axis in cartesian coordinates. Either `x` or
# 20     `y` can optionally be a list of column references or array_likes,  in
# 21     which case the data will be treated as if it were 'wide' rather than
# 22     'long'.
# 24     Either a name of a column in `data_frame`, or a pandas Series or
# 25     array_like object. Values from this column or array_like are used to
# 26     position marks along the y axis in cartesian coordinates. Either `x` or
# 27     `y` can optionally be a list of column references or array_likes,  in
# 28     which case the data will be treated as if it were 'wide' rather than
# 29     'long'.
# 31     Either a name of a column in `data_frame`, or a pandas Series or
# 32     array_like object. Values from this column or array_like are used to
# 33     assign color to marks.
# 35     Either a name of a column in `data_frame`, or a pandas Series or
# 36     array_like object. Values from this column or array_like are used to
# 37     assign marks to facetted subplots in the vertical direction.
# 39     Either a name of a column in `data_frame`, or a pandas Series or
# 40     array_like object. Values from this column or array_like are used to
# 41     assign marks to facetted subplots in the horizontal direction.
# 43     Maximum number of facet columns. Wraps the column variable at this
# 44     width, so that the column facets span multiple rows. Ignored if 0, and
# 45     forced to 0 if `facet_row` or a `marginal` is set.
# 47     Spacing between facet rows, in paper units. Default is 0.03 or 0.0.7
# 48     when facet_col_wrap is used.
# 50     Spacing between facet columns, in paper units Default is 0.02.
# 52     Either a name of a column in `data_frame`, or a pandas Series or
# 53     array_like object. Values from this column or array_like appear in bold
# 54     in the hover tooltip.
# 56     Either a name or list of names of columns in `data_frame`, or pandas
# 57     Series, or array_like objects or a dict with column names as keys, with
# 58     values True (for default formatting) False (in order to remove this
# 59     column from hover information), or a formatting string, for example
# 61     tuples with a bool or formatting string as first element, and list-like
# 62     data to appear in hover as second element Values from these columns
# 63     appear as extra data in the hover tooltip.
# 65     Either name or list of names of columns in `data_frame`, or pandas
# 66     Series, or array_like objects Values from these columns are extra data,
# 67     to be used in widgets or Dash callbacks for example. This data is not
# 68     user-visible but is included in events emitted by the figure (lasso
# 69     selection etc.)
# 71     Either a name of a column in `data_frame`, or a pandas Series or
# 72     array_like object. Values from this column or array_like are used to
# 73     assign marks to animation frames.
# 75     Either a name of a column in `data_frame`, or a pandas Series or
# 76     array_like object. Values from this column or array_like are used to
# 78     `animation_group`s will be treated as if they describe the same object
# 79     in each frame.
# 81     By default, in Python 3.6+, the order of categorical values in axes,
# 82     legends and facets depends on the order in which these values are first
# 83     encountered in `data_frame` (and no order is guaranteed by default in
# 84     Python below 3.6). This parameter is used to force a specific ordering
# 85     of values per column. The keys of this dict should correspond to column
# 86     names, and the values should be lists of strings corresponding to the
# 87     specific display order desired.
# 89     By default, column names are used in the figure for axis titles, legend
# 90     entries and hovers. This parameter allows this to be overridden. The
# 91     keys of this dict should correspond to column names, and the values
# 92     should correspond to the desired label to be displayed.
# 94     Strings should define valid CSS-colors. When `color` is set and the
# 95     values in the corresponding column are not numeric, values in that
# 96     column are assigned colors by cycling through `color_discrete_sequence`
# 97     in the order described in `category_orders`, unless the value of
# 98     `color` is a key in `color_discrete_map`. Various useful color
# 99     sequences are available in the `plotly.express.colors` submodules,
# 100     specifically `plotly.express.colors.qualitative`.
# 102     String values should define valid CSS-colors Used to override
# 103     `color_discrete_sequence` to assign a specific colors to marks
# 104     corresponding with specific values. Keys in `color_discrete_map` should
# 105     be values in the column denoted by `color`. Alternatively, if the
# 106     values of `color` are valid colors, the string `'identity'` may be
# 107     passed to cause them to be used directly.
# 109     (default `'v'` if `x` and `y` are provided and both continous or both
# 110     categorical,  otherwise `'v'`(`'h'`) if `x`(`y`) is categorical and
# 111     `y`(`x`) is continuous,  otherwise `'v'`(`'h'`) if only `x`(`y`) is
# 112     provided)
# 114     One of `'group'` or `'overlay'` In `'overlay'` mode, boxes are on drawn
# 115     top of one another. In `'group'` mode, boxes are placed beside each
# 116     other.
# 118     If `True`, the x-axis is log-scaled in cartesian coordinates.
# 120     If `True`, the y-axis is log-scaled in cartesian coordinates.
# 122     If provided, overrides auto-scaling on the x-axis in cartesian
# 123     coordinates.
# 125     If provided, overrides auto-scaling on the y-axis in cartesian
# 126     coordinates.
# 128     One of `'outliers'`, `'suspectedoutliers'`, `'all'`, or `False`. If
# 129     `'outliers'`, only the sample points lying outside the whiskers are
# 130     shown. If `'suspectedoutliers'`, all outlier points are shown and those
# 131     less than 4*Q1-3*Q3 or greater than 4*Q3-3*Q1 are highlighted with the
# 132     marker's `'outliercolor'`. If `'outliers'`, only the sample points
# 133     lying outside the whiskers are shown. If `'all'`, all sample points are
# 134     shown. If `False`, no sample points are shown and the whiskers extend
# 135     to the full range of the sample.
# 137     If `True`, boxes are drawn with notches.
# 139     The figure title.
# 141     The figure template name (must be a key in plotly.io.templates) or
# 142     definition.
# 144     The figure width in pixels.
# 146     The figure height in pixels.
# 147
# 148 Returns
# 149 -------
# 150     plotly.graph_objects.Figure

# %%
import plotly.express as px
import inspect
import re

plotly_vizu_list = [px.scatter, px.line, px.bar, px.histogram, px.box]

param_info = {}

for func in plotly_vizu_list:
    param_info[func.__name__] = {}
    docstring = func.__doc__
    if not docstring:
        continue

    for line in docstring.split("\n"):
        match = re.search(r"\s*([^\s]+):\s*(.+)", line)
        if match:
            param_name, param_desc = match.groups()
            param_info[func.__name__][param_name] = {
                "description": param_desc.strip(),
                "default": None,
                "options": None,
            }

            signature = inspect.signature(func)
            param = signature.parameters.get(param_name)
            if param and param.default is not inspect.Parameter.empty:
                param_info[func.__name__][param_name]["default"] = param.default

                if param.annotation is not inspect.Parameter.empty:
                    if hasattr(param.annotation, "__args__"):
                        if param.annotation.__args__[0] is not inspect.Parameter.empty and param_name not in ["'", "Optional"]:
                            param_info[func.__name__][param_name]["options"] = param.annotation.__args__[0]
                    elif param.annotation is not None and param_name not in ["'", "Optional"]:
                        param_info[func.__name__][param_name]["options"] = param.annotation

from pprint import pprint
pprint(param_info)
# Out:
# {'bar': {"'": {'default': None,
#                'description': ".3f' or '|%a' or list-like data to appear in "
#                               'the hover tooltip or',
#                'options': None},
#          'Optional': {'default': None,
#                       'description': 'if missing, a DataFrame gets constructed',
#                       'options': None},
#          'animation_frame': {'default': None,
#                              'description': 'str or int or Series or '
#                                             'array-like',
#                              'options': None},
#          'animation_group': {'default': None,
#                              'description': 'str or int or Series or '
#                                             'array-like',
#                              'options': None},
#          'barmode': {'default': 'relative',
#                      'description': "str (default `'relative'`)",
#                      'options': None},
#          'base': {'default': None,
#                   'description': 'str or int or Series or array-like',
#                   'options': None},
#          'category_orders': {'default': None,
#                              'description': 'dict with str keys and list of '
#                                             'str values (default `{}`)',
#                              'options': None},
#          'color': {'default': None,
#                    'description': 'str or int or Series or array-like',
#                    'options': None},
#          'color_continuous_midpoint': {'default': None,
#                                        'description': 'number (default `None`)',
#                                        'options': None},
#          'color_continuous_scale': {'default': None,
#                                     'description': 'list of str',
#                                     'options': None},
#          'color_discrete_map': {'default': None,
#                                 'description': 'dict with str keys and str '
#                                                'values (default `{}`)',
#                                 'options': None},
#          'color_discrete_sequence': {'default': None,
#                                      'description': 'list of str',
#                                      'options': None},
#          'custom_data': {'default': None,
#                          'description': 'str, or list of str or int, or Series '
#                                         'or array-like',
#                          'options': None},
#          'data_frame': {'default': None,
#                         'description': 'DataFrame or array-like or dict',
#                         'options': None},
#          'error_x': {'default': None,
#                      'description': 'str or int or Series or array-like',
#                      'options': None},
#          'error_x_minus': {'default': None,
#                            'description': 'str or int or Series or array-like',
#                            'options': None},
#          'error_y': {'default': None,
#                      'description': 'str or int or Series or array-like',
#                      'options': None},
#          'error_y_minus': {'default': None,
#                            'description': 'str or int or Series or array-like',
#                            'options': None},
#          'facet_col': {'default': None,
#                        'description': 'str or int or Series or array-like',
#                        'options': None},
#          'facet_col_spacing': {'default': None,
#                                'description': 'float between 0 and 1',
#                                'options': None},
#          'facet_col_wrap': {'default': 0,
#                             'description': 'int',
#                             'options': None},
#          'facet_row': {'default': None,
#                        'description': 'str or int or Series or array-like',
#                        'options': None},
#          'facet_row_spacing': {'default': None,
#                                'description': 'float between 0 and 1',
#                                'options': None},
#          'frames': {'default': None,
#                     'description': 'rows with matching',
#                     'options': None},
#          'height': {'default': None,
#                     'description': 'int (default `None`)',
#                     'options': None},
#          'hover_data': {'default': None,
#                         'description': 'str, or list of str or int, or Series '
#                                        'or array-like, or dict',
#                         'options': None},
#          'hover_name': {'default': None,
#                         'description': 'str or int or Series or array-like',
#                         'options': None},
#          'labels': {'default': None,
#                     'description': 'dict with str keys and str values (default '
#                                    '`{}`)',
#                     'options': None},
#          'log_x': {'default': False,
#                    'description': 'boolean (default `False`)',
#                    'options': None},
#          'log_y': {'default': False,
#                    'description': 'boolean (default `False`)',
#                    'options': None},
#          'opacity': {'default': None, 'description': 'float', 'options': None},
#          'orientation': {'default': None,
#                          'description': "str, one of `'h'` for horizontal or "
#                                         "`'v'` for vertical.",
#                          'options': None},
#          'pattern_shape': {'default': None,
#                            'description': 'str or int or Series or array-like',
#                            'options': None},
#          'pattern_shape_map': {'default': None,
#                                'description': 'dict with str keys and str '
#                                               'values (default `{}`)',
#                                'options': None},
#          'pattern_shape_sequence': {'default': None,
#                                     'description': 'list of str',
#                                     'options': None},
#          'range_color': {'default': None,
#                          'description': 'list of two numbers',
#                          'options': None},
#          'range_x': {'default': None,
#                      'description': 'list of two numbers',
#                      'options': None},
#          'range_y': {'default': None,
#                      'description': 'list of two numbers',
#                      'options': None},
#          'template': {'default': None,
#                       'description': 'str or dict or '
#                                      'plotly.graph_objects.layout.Template '
#                                      'instance',
#                       'options': None},
#          'text': {'default': None,
#                   'description': 'str or int or Series or array-like',
#                   'options': None},
#          'text_auto': {'default': False,
#                        'description': 'bool or string (default `False`)',
#                        'options': None},
#          'title': {'default': None, 'description': 'str', 'options': None},
#          'width': {'default': None,
#                    'description': 'int (default `None`)',
#                    'options': None},
#          'x': {'default': None,
#                'description': 'str or int or Series or array-like',
#                'options': None},
#          'y': {'default': None,
#                'description': 'str or int or Series or array-like',
#                'options': None}},
#  'box': {"'": {'default': None,
#                'description': ".3f' or '|%a' or list-like data to appear in "
#                               'the hover tooltip or',
#                'options': None},
#          '(IQR': {'default': None,
#                   'description': 'Q3-Q1), see "points" for other options.',
#                   'options': None},
#          'Optional': {'default': None,
#                       'description': 'if missing, a DataFrame gets constructed',
#                       'options': None},
#          'animation_frame': {'default': None,
#                              'description': 'str or int or Series or '
#                                             'array-like',
#                              'options': None},
#          'animation_group': {'default': None,
#                              'description': 'str or int or Series or '
#                                             'array-like',
#                              'options': None},
#          'boxmode': {'default': None,
#                      'description': "str (default `'group'`)",
#                      'options': None},
#          'category_orders': {'default': None,
#                              'description': 'dict with str keys and list of '
#                                             'str values (default `{}`)',
#                              'options': None},
#          'color': {'default': None,
#                    'description': 'str or int or Series or array-like',
#                    'options': None},
#          'color_discrete_map': {'default': None,
#                                 'description': 'dict with str keys and str '
#                                                'values (default `{}`)',
#                                 'options': None},
#          'color_discrete_sequence': {'default': None,
#                                      'description': 'list of str',
#                                      'options': None},
#          'custom_data': {'default': None,
#                          'description': 'str, or list of str or int, or Series '
#                                         'or array-like',
#                          'options': None},
#          'data_frame': {'default': None,
#                         'description': 'DataFrame or array-like or dict',
#                         'options': None},
#          'facet_col': {'default': None,
#                        'description': 'str or int or Series or array-like',
#                        'options': None},
#          'facet_col_spacing': {'default': None,
#                                'description': 'float between 0 and 1',
#                                'options': None},
#          'facet_col_wrap': {'default': 0,
#                             'description': 'int',
#                             'options': None},
#          'facet_row': {'default': None,
#                        'description': 'str or int or Series or array-like',
#                        'options': None},
#          'facet_row_spacing': {'default': None,
#                                'description': 'float between 0 and 1',
#                                'options': None},
#          'frames': {'default': None,
#                     'description': 'rows with matching',
#                     'options': None},
#          'height': {'default': None,
#                     'description': 'int (default `None`)',
#                     'options': None},
#          'hover_data': {'default': None,
#                         'description': 'str, or list of str or int, or Series '
#                                        'or array-like, or dict',
#                         'options': None},
#          'hover_name': {'default': None,
#                         'description': 'str or int or Series or array-like',
#                         'options': None},
#          'labels': {'default': None,
#                     'description': 'dict with str keys and str values (default '
#                                    '`{}`)',
#                     'options': None},
#          'log_x': {'default': False,
#                    'description': 'boolean (default `False`)',
#                    'options': None},
#          'log_y': {'default': False,
#                    'description': 'boolean (default `False`)',
#                    'options': None},
#          'notched': {'default': False,
#                      'description': 'boolean (default `False`)',
#                      'options': None},
#          'orientation': {'default': None,
#                          'description': "str, one of `'h'` for horizontal or "
#                                         "`'v'` for vertical.",
#                          'options': None},
#          'points': {'default': None,
#                     'description': "str or boolean (default `'outliers'`)",
#                     'options': None},
#          'range_x': {'default': None,
#                      'description': 'list of two numbers',
#                      'options': None},
#          'range_y': {'default': None,
#                      'description': 'list of two numbers',
#                      'options': None},
#          'template': {'default': None,
#                       'description': 'str or dict or '
#                                      'plotly.graph_objects.layout.Template '
#                                      'instance',
#                       'options': None},
#          'title': {'default': None, 'description': 'str', 'options': None},
#          'width': {'default': None,
#                    'description': 'int (default `None`)',
#                    'options': None},
#          'x': {'default': None,
#                'description': 'str or int or Series or array-like',
#                'options': None},
#          'y': {'default': None,
#                'description': 'str or int or Series or array-like',
#                'options': None}},
#  'histogram': {"'": {'default': None,
#                      'description': ".3f' or '|%a' or list-like data to appear "
#                                     'in the hover tooltip or',
#                      'options': None},
#                '(note': {'default': None,
#                          'description': 'can be normalized with',
#                          'options': None},
#                'Optional': {'default': None,
#                             'description': 'if missing, a DataFrame gets '
#                                            'constructed',
#                             'options': None},
#                'animation_frame': {'default': None,
#                                    'description': 'str or int or Series or '
#                                                   'array-like',
#                                    'options': None},
#                'animation_group': {'default': None,
#                                    'description': 'str or int or Series or '
#                                                   'array-like',
#                                    'options': None},
#                'barmode': {'default': 'relative',
#                            'description': "str (default `'relative'`)",
#                            'options': None},
#                'barnorm': {'default': None,
#                            'description': 'str (default `None`)',
#                            'options': None},
#                'category_orders': {'default': None,
#                                    'description': 'dict with str keys and list '
#                                                   'of str values (default '
#                                                   '`{}`)',
#                                    'options': None},
#                'color': {'default': None,
#                          'description': 'str or int or Series or array-like',
#                          'options': None},
#                'color_discrete_map': {'default': None,
#                                       'description': 'dict with str keys and '
#                                                      'str values (default '
#                                                      '`{}`)',
#                                       'options': None},
#                'color_discrete_sequence': {'default': None,
#                                            'description': 'list of str',
#                                            'options': None},
#                'cumulative': {'default': None,
#                               'description': 'boolean (default `False`)',
#                               'options': None},
#                'data_frame': {'default': None,
#                               'description': 'DataFrame or array-like or dict',
#                               'options': None},
#                'facet_col': {'default': None,
#                              'description': 'str or int or Series or '
#                                             'array-like',
#                              'options': None},
#                'facet_col_spacing': {'default': None,
#                                      'description': 'float between 0 and 1',
#                                      'options': None},
#                'facet_col_wrap': {'default': 0,
#                                   'description': 'int',
#                                   'options': None},
#                'facet_row': {'default': None,
#                              'description': 'str or int or Series or '
#                                             'array-like',
#                              'options': None},
#                'facet_row_spacing': {'default': None,
#                                      'description': 'float between 0 and 1',
#                                      'options': None},
#                'frames': {'default': None,
#                           'description': 'rows with matching',
#                           'options': None},
#                'height': {'default': None,
#                           'description': 'int (default `None`)',
#                           'options': None},
#                'histfunc': {'default': None,
#                             'description': "str (default `'count'` if no "
#                                            'arguments are provided, else '
#                                            "`'sum'`)",
#                             'options': None},
#                'histnorm': {'default': None,
#                             'description': 'str (default `None`)',
#                             'options': None},
#                'hover_data': {'default': None,
#                               'description': 'str, or list of str or int, or '
#                                              'Series or array-like, or dict',
#                               'options': None},
#                'hover_name': {'default': None,
#                               'description': 'str or int or Series or '
#                                              'array-like',
#                               'options': None},
#                'labels': {'default': None,
#                           'description': 'dict with str keys and str values '
#                                          '(default `{}`)',
#                           'options': None},
#                'log_x': {'default': False,
#                          'description': 'boolean (default `False`)',
#                          'options': None},
#                'log_y': {'default': False,
#                          'description': 'boolean (default `False`)',
#                          'options': None},
#                'marginal': {'default': None,
#                             'description': 'str',
#                             'options': None},
#                'nbins': {'default': None,
#                          'description': 'int',
#                          'options': None},
#                'opacity': {'default': None,
#                            'description': 'float',
#                            'options': None},
#                'orientation': {'default': None,
#                                'description': "str, one of `'h'` for "
#                                               "horizontal or `'v'` for "
#                                               'vertical.',
#                                'options': None},
#                'pattern_shape': {'default': None,
#                                  'description': 'str or int or Series or '
#                                                 'array-like',
#                                  'options': None},
#                'pattern_shape_map': {'default': None,
#                                      'description': 'dict with str keys and '
#                                                     'str values (default `{}`)',
#                                      'options': None},
#                'pattern_shape_sequence': {'default': None,
#                                           'description': 'list of str',
#                                           'options': None},
#                'range_x': {'default': None,
#                            'description': 'list of two numbers',
#                            'options': None},
#                'range_y': {'default': None,
#                            'description': 'list of two numbers',
#                            'options': None},
#                'template': {'default': None,
#                             'description': 'str or dict or '
#                                            'plotly.graph_objects.layout.Template '
#                                            'instance',
#                             'options': None},
#                'text_auto': {'default': False,
#                              'description': 'bool or string (default `False`)',
#                              'options': None},
#                'title': {'default': None,
#                          'description': 'str',
#                          'options': None},
#                'width': {'default': None,
#                          'description': 'int (default `None`)',
#                          'options': None},
#                'x': {'default': None,
#                      'description': 'str or int or Series or array-like',
#                      'options': None},
#                'y': {'default': None,
#                      'description': 'str or int or Series or array-like',
#                      'options': None}},
#  'line': {"'": {'default': None,
#                 'description': ".3f' or '|%a' or list-like data to appear in "
#                                'the hover tooltip or',
#                 'options': None},
#           'Optional': {'default': None,
#                        'description': 'if missing, a DataFrame gets '
#                                       'constructed',
#                        'options': None},
#           'animation_frame': {'default': None,
#                               'description': 'str or int or Series or '
#                                              'array-like',
#                               'options': None},
#           'animation_group': {'default': None,
#                               'description': 'str or int or Series or '
#                                              'array-like',
#                               'options': None},
#           'category_orders': {'default': None,
#                               'description': 'dict with str keys and list of '
#                                              'str values (default `{}`)',
#                               'options': None},
#           'color': {'default': None,
#                     'description': 'str or int or Series or array-like',
#                     'options': None},
#           'color_discrete_map': {'default': None,
#                                  'description': 'dict with str keys and str '
#                                                 'values (default `{}`)',
#                                  'options': None},
#           'color_discrete_sequence': {'default': None,
#                                       'description': 'list of str',
#                                       'options': None},
#           'custom_data': {'default': None,
#                           'description': 'str, or list of str or int, or '
#                                          'Series or array-like',
#                           'options': None},
#           'data_frame': {'default': None,
#                          'description': 'DataFrame or array-like or dict',
#                          'options': None},
#           'error_x': {'default': None,
#                       'description': 'str or int or Series or array-like',
#                       'options': None},
#           'error_x_minus': {'default': None,
#                             'description': 'str or int or Series or array-like',
#                             'options': None},
#           'error_y': {'default': None,
#                       'description': 'str or int or Series or array-like',
#                       'options': None},
#           'error_y_minus': {'default': None,
#                             'description': 'str or int or Series or array-like',
#                             'options': None},
#           'facet_col': {'default': None,
#                         'description': 'str or int or Series or array-like',
#                         'options': None},
#           'facet_col_spacing': {'default': None,
#                                 'description': 'float between 0 and 1',
#                                 'options': None},
#           'facet_col_wrap': {'default': 0,
#                              'description': 'int',
#                              'options': None},
#           'facet_row': {'default': None,
#                         'description': 'str or int or Series or array-like',
#                         'options': None},
#           'facet_row_spacing': {'default': None,
#                                 'description': 'float between 0 and 1',
#                                 'options': None},
#           'frames': {'default': None,
#                      'description': 'rows with matching',
#                      'options': None},
#           'height': {'default': None,
#                      'description': 'int (default `None`)',
#                      'options': None},
#           'hover_data': {'default': None,
#                          'description': 'str, or list of str or int, or Series '
#                                         'or array-like, or dict',
#                          'options': None},
#           'hover_name': {'default': None,
#                          'description': 'str or int or Series or array-like',
#                          'options': None},
#           'labels': {'default': None,
#                      'description': 'dict with str keys and str values '
#                                     '(default `{}`)',
#                      'options': None},
#           'line_dash': {'default': None,
#                         'description': 'str or int or Series or array-like',
#                         'options': None},
#           'line_dash_map': {'default': None,
#                             'description': 'dict with str keys and str values '
#                                            '(default `{}`)',
#                             'options': None},
#           'line_dash_sequence': {'default': None,
#                                  'description': 'list of str',
#                                  'options': None},
#           'line_group': {'default': None,
#                          'description': 'str or int or Series or array-like',
#                          'options': None},
#           'line_shape': {'default': None,
#                          'description': "str (default `'linear'`)",
#                          'options': None},
#           'log_x': {'default': False,
#                     'description': 'boolean (default `False`)',
#                     'options': None},
#           'log_y': {'default': False,
#                     'description': 'boolean (default `False`)',
#                     'options': None},
#           'markers': {'default': False,
#                       'description': 'boolean (default `False`)',
#                       'options': None},
#           'orientation': {'default': None,
#                           'description': "str, one of `'h'` for horizontal or "
#                                          "`'v'` for vertical.",
#                           'options': None},
#           'range_x': {'default': None,
#                       'description': 'list of two numbers',
#                       'options': None},
#           'range_y': {'default': None,
#                       'description': 'list of two numbers',
#                       'options': None},
#           'render_mode': {'default': 'auto',
#                           'description': 'str',
#                           'options': None},
#           'symbol': {'default': None,
#                      'description': 'str or int or Series or array-like',
#                      'options': None},
#           'symbol_map': {'default': None,
#                          'description': 'dict with str keys and str values '
#                                         '(default `{}`)',
#                          'options': None},
#           'symbol_sequence': {'default': None,
#                               'description': 'list of str',
#                               'options': None},
#           'template': {'default': None,
#                        'description': 'str or dict or '
#                                       'plotly.graph_objects.layout.Template '
#                                       'instance',
#                        'options': None},
#           'text': {'default': None,
#                    'description': 'str or int or Series or array-like',
#                    'options': None},
#           'title': {'default': None, 'description': 'str', 'options': None},
#           'width': {'default': None,
#                     'description': 'int (default `None`)',
#                     'options': None},
#           'x': {'default': None,
#                 'description': 'str or int or Series or array-like',
#                 'options': None},
#           'y': {'default': None,
#                 'description': 'str or int or Series or array-like',
#                 'options': None}},
#  'scatter': {"'": {'default': None,
#                    'description': ".3f' or '|%a' or list-like data to appear "
#                                   'in the hover tooltip or',
#                    'options': None},
#              'Optional': {'default': None,
#                           'description': 'if missing, a DataFrame gets '
#                                          'constructed',
#                           'options': None},
#              'animation_frame': {'default': None,
#                                  'description': 'str or int or Series or '
#                                                 'array-like',
#                                  'options': None},
#              'animation_group': {'default': None,
#                                  'description': 'str or int or Series or '
#                                                 'array-like',
#                                  'options': None},
#              'category_orders': {'default': None,
#                                  'description': 'dict with str keys and list '
#                                                 'of str values (default `{}`)',
#                                  'options': None},
#              'color': {'default': None,
#                        'description': 'str or int or Series or array-like',
#                        'options': None},
#              'color_continuous_midpoint': {'default': None,
#                                            'description': 'number (default '
#                                                           '`None`)',
#                                            'options': None},
#              'color_continuous_scale': {'default': None,
#                                         'description': 'list of str',
#                                         'options': None},
#              'color_discrete_map': {'default': None,
#                                     'description': 'dict with str keys and str '
#                                                    'values (default `{}`)',
#                                     'options': None},
#              'color_discrete_sequence': {'default': None,
#                                          'description': 'list of str',
#                                          'options': None},
#              'custom_data': {'default': None,
#                              'description': 'str, or list of str or int, or '
#                                             'Series or array-like',
#                              'options': None},
#              'data_frame': {'default': None,
#                             'description': 'DataFrame or array-like or dict',
#                             'options': None},
#              'error_x': {'default': None,
#                          'description': 'str or int or Series or array-like',
#                          'options': None},
#              'error_x_minus': {'default': None,
#                                'description': 'str or int or Series or '
#                                               'array-like',
#                                'options': None},
#              'error_y': {'default': None,
#                          'description': 'str or int or Series or array-like',
#                          'options': None},
#              'error_y_minus': {'default': None,
#                                'description': 'str or int or Series or '
#                                               'array-like',
#                                'options': None},
#              'facet_col': {'default': None,
#                            'description': 'str or int or Series or array-like',
#                            'options': None},
#              'facet_col_spacing': {'default': None,
#                                    'description': 'float between 0 and 1',
#                                    'options': None},
#              'facet_col_wrap': {'default': 0,
#                                 'description': 'int',
#                                 'options': None},
#              'facet_row': {'default': None,
#                            'description': 'str or int or Series or array-like',
#                            'options': None},
#              'facet_row_spacing': {'default': None,
#                                    'description': 'float between 0 and 1',
#                                    'options': None},
#              'frames': {'default': None,
#                         'description': 'rows with matching',
#                         'options': None},
#              'height': {'default': None,
#                         'description': 'int (default `None`)',
#                         'options': None},
#              'hover_data': {'default': None,
#                             'description': 'str, or list of str or int, or '
#                                            'Series or array-like, or dict',
#                             'options': None},
#              'hover_name': {'default': None,
#                             'description': 'str or int or Series or array-like',
#                             'options': None},
#              'labels': {'default': None,
#                         'description': 'dict with str keys and str values '
#                                        '(default `{}`)',
#                         'options': None},
#              'log_x': {'default': False,
#                        'description': 'boolean (default `False`)',
#                        'options': None},
#              'log_y': {'default': False,
#                        'description': 'boolean (default `False`)',
#                        'options': None},
#              'marginal_x': {'default': None,
#                             'description': 'str',
#                             'options': None},
#              'marginal_y': {'default': None,
#                             'description': 'str',
#                             'options': None},
#              'opacity': {'default': None,
#                          'description': 'float',
#                          'options': None},
#              'orientation': {'default': None,
#                              'description': "str, one of `'h'` for horizontal "
#                                             "or `'v'` for vertical.",
#                              'options': None},
#              'range_color': {'default': None,
#                              'description': 'list of two numbers',
#                              'options': None},
#              'range_x': {'default': None,
#                          'description': 'list of two numbers',
#                          'options': None},
#              'range_y': {'default': None,
#                          'description': 'list of two numbers',
#                          'options': None},
#              'render_mode': {'default': 'auto',
#                              'description': 'str',
#                              'options': None},
#              'size': {'default': None,
#                       'description': 'str or int or Series or array-like',
#                       'options': None},
#              'size_max': {'default': None,
#                           'description': 'int (default `20`)',
#                           'options': None},
#              'symbol': {'default': None,
#                         'description': 'str or int or Series or array-like',
#                         'options': None},
#              'symbol_map': {'default': None,
#                             'description': 'dict with str keys and str values '
#                                            '(default `{}`)',
#                             'options': None},
#              'symbol_sequence': {'default': None,
#                                  'description': 'list of str',
#                                  'options': None},
#              'template': {'default': None,
#                           'description': 'str or dict or '
#                                          'plotly.graph_objects.layout.Template '
#                                          'instance',
#                           'options': None},
#              'text': {'default': None,
#                       'description': 'str or int or Series or array-like',
#                       'options': None},
#              'title': {'default': None, 'description': 'str', 'options': None},
#              'trendline': {'default': None,
#                            'description': 'str',
#                            'options': None},
#              'trendline_color_override': {'default': None,
#                                           'description': 'str',
#                                           'options': None},
#              'trendline_options': {'default': None,
#                                    'description': 'dict',
#                                    'options': None},
#              'trendline_scope': {'default': 'trace',
#                                  'description': "str (one of `'trace'` or "
#                                                 "`'overall'`, default "
#                                                 "`'trace'`)",
#                                  'options': None},
#              'width': {'default': None,
#                        'description': 'int (default `None`)',
#                        'options': None},
#              'x': {'default': None,
#                    'description': 'str or int or Series or array-like',
#                    'options': None},
#              'y': {'default': None,
#                    'description': 'str or int or Series or array-like',
#                    'options': None}}}

# %%
import plotly.express as px
import inspect
import re

plotly_vizu_list = [px.scatter, px.line, px.bar, px.histogram, px.box]

param_info = {}

# for func in plotly_vizu_list:
    # param_info[func.__name__] = {}
docstring = plotly_vizu_list[0].__doc__
print(docstring)
# Out:
#     In a scatter plot, each row of `data_frame` is represented by a symbol
#     mark in 2D space.
#
# Parameters
# ----------
# data_frame: DataFrame or array-like or dict
#     This argument needs to be passed for column names (and not keyword
#     names) to be used. Array-like and dict are transformed internally to a
#     pandas DataFrame. Optional: if missing, a DataFrame gets constructed
#     under the hood using the other arguments.
# x: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the x axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# y: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     position marks along the y axis in cartesian coordinates. Either `x` or
#     `y` can optionally be a list of column references or array_likes,  in
#     which case the data will be treated as if it were 'wide' rather than
#     'long'.
# color: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign color to marks.
# symbol: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign symbols to marks.
# size: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign mark sizes.
# hover_name: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like appear in bold
#     in the hover tooltip.
# hover_data: str, or list of str or int, or Series or array-like, or dict
#     Either a name or list of names of columns in `data_frame`, or pandas
#     Series, or array_like objects or a dict with column names as keys, with
#     values True (for default formatting) False (in order to remove this
#     column from hover information), or a formatting string, for example
#     ':.3f' or '|%a' or list-like data to appear in the hover tooltip or
#     tuples with a bool or formatting string as first element, and list-like
#     data to appear in hover as second element Values from these columns
#     appear as extra data in the hover tooltip.
# custom_data: str, or list of str or int, or Series or array-like
#     Either name or list of names of columns in `data_frame`, or pandas
#     Series, or array_like objects Values from these columns are extra data,
#     to be used in widgets or Dash callbacks for example. This data is not
#     user-visible but is included in events emitted by the figure (lasso
#     selection etc.)
# text: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like appear in the
#     figure as text labels.
# facet_row: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to facetted subplots in the vertical direction.
# facet_col: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to facetted subplots in the horizontal direction.
# facet_col_wrap: int
#     Maximum number of facet columns. Wraps the column variable at this
#     width, so that the column facets span multiple rows. Ignored if 0, and
#     forced to 0 if `facet_row` or a `marginal` is set.
# facet_row_spacing: float between 0 and 1
#     Spacing between facet rows, in paper units. Default is 0.03 or 0.0.7
#     when facet_col_wrap is used.
# facet_col_spacing: float between 0 and 1
#     Spacing between facet columns, in paper units Default is 0.02.
# error_x: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size x-axis error bars. If `error_x_minus` is `None`, error bars will
#     be symmetrical, otherwise `error_x` is used for the positive direction
#     only.
# error_x_minus: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size x-axis error bars in the negative direction. Ignored if `error_x`
#     is `None`.
# error_y: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size y-axis error bars. If `error_y_minus` is `None`, error bars will
#     be symmetrical, otherwise `error_y` is used for the positive direction
#     only.
# error_y_minus: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     size y-axis error bars in the negative direction. Ignored if `error_y`
#     is `None`.
# animation_frame: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     assign marks to animation frames.
# animation_group: str or int or Series or array-like
#     Either a name of a column in `data_frame`, or a pandas Series or
#     array_like object. Values from this column or array_like are used to
#     provide object-constancy across animation frames: rows with matching
#     `animation_group`s will be treated as if they describe the same object
#     in each frame.
# category_orders: dict with str keys and list of str values (default `{}`)
#     By default, in Python 3.6+, the order of categorical values in axes,
#     legends and facets depends on the order in which these values are first
#     encountered in `data_frame` (and no order is guaranteed by default in
#     Python below 3.6). This parameter is used to force a specific ordering
#     of values per column. The keys of this dict should correspond to column
#     names, and the values should be lists of strings corresponding to the
#     specific display order desired.
# labels: dict with str keys and str values (default `{}`)
#     By default, column names are used in the figure for axis titles, legend
#     entries and hovers. This parameter allows this to be overridden. The
#     keys of this dict should correspond to column names, and the values
#     should correspond to the desired label to be displayed.
# orientation: str, one of `'h'` for horizontal or `'v'` for vertical.
#     (default `'v'` if `x` and `y` are provided and both continous or both
#     categorical,  otherwise `'v'`(`'h'`) if `x`(`y`) is categorical and
#     `y`(`x`) is continuous,  otherwise `'v'`(`'h'`) if only `x`(`y`) is
#     provided)
# color_discrete_sequence: list of str
#     Strings should define valid CSS-colors. When `color` is set and the
#     values in the corresponding column are not numeric, values in that
#     column are assigned colors by cycling through `color_discrete_sequence`
#     in the order described in `category_orders`, unless the value of
#     `color` is a key in `color_discrete_map`. Various useful color
#     sequences are available in the `plotly.express.colors` submodules,
#     specifically `plotly.express.colors.qualitative`.
# color_discrete_map: dict with str keys and str values (default `{}`)
#     String values should define valid CSS-colors Used to override
#     `color_discrete_sequence` to assign a specific colors to marks
#     corresponding with specific values. Keys in `color_discrete_map` should
#     be values in the column denoted by `color`. Alternatively, if the
#     values of `color` are valid colors, the string `'identity'` may be
#     passed to cause them to be used directly.
# color_continuous_scale: list of str
#     Strings should define valid CSS-colors This list is used to build a
#     continuous color scale when the column denoted by `color` contains
#     numeric data. Various useful color scales are available in the
#     `plotly.express.colors` submodules, specifically
#     `plotly.express.colors.sequential`, `plotly.express.colors.diverging`
#     and `plotly.express.colors.cyclical`.
# range_color: list of two numbers
#     If provided, overrides auto-scaling on the continuous color scale.
# color_continuous_midpoint: number (default `None`)
#     If set, computes the bounds of the continuous color scale to have the
#     desired midpoint. Setting this value is recommended when using
#     `plotly.express.colors.diverging` color scales as the inputs to
#     `color_continuous_scale`.
# symbol_sequence: list of str
#     Strings should define valid plotly.js symbols. When `symbol` is set,
#     values in that column are assigned symbols by cycling through
#     `symbol_sequence` in the order described in `category_orders`, unless
#     the value of `symbol` is a key in `symbol_map`.
# symbol_map: dict with str keys and str values (default `{}`)
#     String values should define plotly.js symbols Used to override
#     `symbol_sequence` to assign a specific symbols to marks corresponding
#     with specific values. Keys in `symbol_map` should be values in the
#     column denoted by `symbol`. Alternatively, if the values of `symbol`
#     are valid symbol names, the string `'identity'` may be passed to cause
#     them to be used directly.
# opacity: float
#     Value between 0 and 1. Sets the opacity for markers.
# size_max: int (default `20`)
#     Set the maximum mark size when using `size`.
# marginal_x: str
#     One of `'rug'`, `'box'`, `'violin'`, or `'histogram'`. If set, a
#     horizontal subplot is drawn above the main plot, visualizing the
#     x-distribution.
# marginal_y: str
#     One of `'rug'`, `'box'`, `'violin'`, or `'histogram'`. If set, a
#     vertical subplot is drawn to the right of the main plot, visualizing
#     the y-distribution.
# trendline: str
#     One of `'ols'`, `'lowess'`, `'rolling'`, `'expanding'` or `'ewm'`. If
#     `'ols'`, an Ordinary Least Squares regression line will be drawn for
#     each discrete-color/symbol group. If `'lowess`', a Locally Weighted
#     Scatterplot Smoothing line will be drawn for each discrete-color/symbol
#     group. If `'rolling`', a Rolling (e.g. rolling average, rolling median)
#     line will be drawn for each discrete-color/symbol group. If
#     `'expanding`', an Expanding (e.g. expanding average, expanding sum)
#     line will be drawn for each discrete-color/symbol group. If `'ewm`', an
#     Exponentially Weighted Moment (e.g. exponentially-weighted moving
#     average) line will be drawn for each discrete-color/symbol group. See
#     the docstrings for the functions in
#     `plotly.express.trendline_functions` for more details on these
#     functions and how to configure them with the `trendline_options`
#     argument.
# trendline_options: dict
#     Options passed as the first argument to the function from
#     `plotly.express.trendline_functions`  named in the `trendline`
#     argument.
# trendline_color_override: str
#     Valid CSS color. If provided, and if `trendline` is set, all trendlines
#     will be drawn in this color rather than in the same color as the traces
#     from which they draw their inputs.
# trendline_scope: str (one of `'trace'` or `'overall'`, default `'trace'`)
#     If `'trace'`, then one trendline is drawn per trace (i.e. per color,
#     symbol, facet, animation frame etc) and if `'overall'` then one
#     trendline is computed for the entire dataset, and replicated across all
#     facets.
# log_x: boolean (default `False`)
#     If `True`, the x-axis is log-scaled in cartesian coordinates.
# log_y: boolean (default `False`)
#     If `True`, the y-axis is log-scaled in cartesian coordinates.
# range_x: list of two numbers
#     If provided, overrides auto-scaling on the x-axis in cartesian
#     coordinates.
# range_y: list of two numbers
#     If provided, overrides auto-scaling on the y-axis in cartesian
#     coordinates.
# render_mode: str
#     One of `'auto'`, `'svg'` or `'webgl'`, default `'auto'` Controls the
#     browser API used to draw marks. `'svg`' is appropriate for figures of
#     less than 1000 data points, and will allow for fully-vectorized output.
#     `'webgl'` is likely necessary for acceptable performance above 1000
#     points but rasterizes part of the output.  `'auto'` uses heuristics to
#     choose the mode.
# title: str
#     The figure title.
# template: str or dict or plotly.graph_objects.layout.Template instance
#     The figure template name (must be a key in plotly.io.templates) or
#     definition.
# width: int (default `None`)
#     The figure width in pixels.
# height: int (default `None`)
#     The figure height in pixels.
#
# Returns
# -------
#     plotly.graph_objects.Figure

# %%
import plotly.express as px
import inspect
import re

plotly_vizu_list = [px.scatter, px.line, px.bar, px.histogram, px.box]

param_info = {}

# for func in plotly_vizu_list:
    # param_info[func.__name__] = {}
docstring = plotly_vizu_list[0].__doc__
# print(docstring)

# docstring = '''
#     # Put the entire docstring here
# '''


def extract_info_from_docstring(docstring):
    lines = docstring.split("\n")
    # print(lines)
    parameters_section = False
    result = {}

    for line in lines:
        # print(line)
        if line.startswith("Parameters"):
            parameters_section = True
            continue
        if parameters_section:
            # if line.startswith("----------"):
            #     break
            if line.startswith("    ") is False:
                print(line.split(': '))
                line_processed = line.split(': ')
                parameter, type = line_processed[0], line_processed[1]
                
                result[parameter] = {"type" : type} 

            elif line.startswith("    ") is True:
                result[-1] += " " + line.strip()

    return result

parameters_info = extract_info_from_docstring(docstring)
for info in parameters_info:
    print(info)
    print()
# Out:
# ['----------']
# ['data_frame', 'DataFrame or array-like or dict']
# ['x', 'str or int or Series or array-like']
# ['y', 'str or int or Series or array-like']
# ['color', 'str or int or Series or array-like']
# ['symbol', 'str or int or Series or array-like']
# ['size', 'str or int or Series or array-like']
# ['hover_name', 'str or int or Series or array-like']
# ['hover_data', 'str, or list of str or int, or Series or array-like, or dict']
# ['custom_data', 'str, or list of str or int, or Series or array-like']
# ['text', 'str or int or Series or array-like']
# ['facet_row', 'str or int or Series or array-like']
# ['facet_col', 'str or int or Series or array-like']
# ['facet_col_wrap', 'int']
# ['facet_row_spacing', 'float between 0 and 1']
# ['facet_col_spacing', 'float between 0 and 1']
# ['error_x', 'str or int or Series or array-like']
# ['error_x_minus', 'str or int or Series or array-like']
# ['error_y', 'str or int or Series or array-like']
# ['error_y_minus', 'str or int or Series or array-like']
# ['animation_frame', 'str or int or Series or array-like']
# ['animation_group', 'str or int or Series or array-like']
# ['category_orders', 'dict with str keys and list of str values (default `{}`)']
# ['labels', 'dict with str keys and str values (default `{}`)']
# ['orientation', "str, one of `'h'` for horizontal or `'v'` for vertical. "]
# ['color_discrete_sequence', 'list of str']
# ['color_discrete_map', 'dict with str keys and str values (default `{}`)']
# ['color_continuous_scale', 'list of str']
# ['range_color', 'list of two numbers']
# ['color_continuous_midpoint', 'number (default `None`)']
# ['symbol_sequence', 'list of str']
# ['symbol_map', 'dict with str keys and str values (default `{}`)']
# ['opacity', 'float']
# ['size_max', 'int (default `20`)']
# ['marginal_x', 'str']
# ['marginal_y', 'str']
# ['trendline', 'str']
# ['trendline_options', 'dict']
# ['trendline_color_override', 'str']
# ['trendline_scope', "str (one of `'trace'` or `'overall'`, default `'trace'`)"]
# ['log_x', 'boolean (default `False`)']
# ['log_y', 'boolean (default `False`)']
# ['range_x', 'list of two numbers']
# ['range_y', 'list of two numbers']
# ['render_mode', 'str']
# ['title', 'str']
# ['template', 'str or dict or plotly.graph_objects.layout.Template instance']
# ['width', 'int (default `None`)']
# ['height', 'int (default `None`)']
# ['']
# ['Returns']
# ['-------']
# ----------
#
# data_frame: DataFrame or array-like or dict This argument needs to be passed for column names (and not keyword names) to be used. Array-like and dict are transformed internally to a pandas DataFrame. Optional: if missing, a DataFrame gets constructed under the hood using the other arguments.
#
# x: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to position marks along the x axis in cartesian coordinates. Either `x` or `y` can optionally be a list of column references or array_likes,  in which case the data will be treated as if it were 'wide' rather than 'long'.
#
# y: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to position marks along the y axis in cartesian coordinates. Either `x` or `y` can optionally be a list of column references or array_likes,  in which case the data will be treated as if it were 'wide' rather than 'long'.
#
# color: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to assign color to marks.
#
# symbol: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to assign symbols to marks.
#
# size: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to assign mark sizes.
#
# hover_name: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like appear in bold in the hover tooltip.
#
# hover_data: str, or list of str or int, or Series or array-like, or dict Either a name or list of names of columns in `data_frame`, or pandas Series, or array_like objects or a dict with column names as keys, with values True (for default formatting) False (in order to remove this column from hover information), or a formatting string, for example ':.3f' or '|%a' or list-like data to appear in the hover tooltip or tuples with a bool or formatting string as first element, and list-like data to appear in hover as second element Values from these columns appear as extra data in the hover tooltip.
#
# custom_data: str, or list of str or int, or Series or array-like Either name or list of names of columns in `data_frame`, or pandas Series, or array_like objects Values from these columns are extra data, to be used in widgets or Dash callbacks for example. This data is not user-visible but is included in events emitted by the figure (lasso selection etc.)
#
# text: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like appear in the figure as text labels.
#
# facet_row: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to assign marks to facetted subplots in the vertical direction.
#
# facet_col: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to assign marks to facetted subplots in the horizontal direction.
#
# facet_col_wrap: int Maximum number of facet columns. Wraps the column variable at this width, so that the column facets span multiple rows. Ignored if 0, and forced to 0 if `facet_row` or a `marginal` is set.
#
# facet_row_spacing: float between 0 and 1 Spacing between facet rows, in paper units. Default is 0.03 or 0.0.7 when facet_col_wrap is used.
#
# facet_col_spacing: float between 0 and 1 Spacing between facet columns, in paper units Default is 0.02.
#
# error_x: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to size x-axis error bars. If `error_x_minus` is `None`, error bars will be symmetrical, otherwise `error_x` is used for the positive direction only.
#
# error_x_minus: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to size x-axis error bars in the negative direction. Ignored if `error_x` is `None`.
#
# error_y: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to size y-axis error bars. If `error_y_minus` is `None`, error bars will be symmetrical, otherwise `error_y` is used for the positive direction only.
#
# error_y_minus: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to size y-axis error bars in the negative direction. Ignored if `error_y` is `None`.
#
# animation_frame: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to assign marks to animation frames.
#
# animation_group: str or int or Series or array-like Either a name of a column in `data_frame`, or a pandas Series or array_like object. Values from this column or array_like are used to provide object-constancy across animation frames: rows with matching `animation_group`s will be treated as if they describe the same object in each frame.
#
# category_orders: dict with str keys and list of str values (default `{}`) By default, in Python 3.6+, the order of categorical values in axes, legends and facets depends on the order in which these values are first encountered in `data_frame` (and no order is guaranteed by default in Python below 3.6). This parameter is used to force a specific ordering of values per column. The keys of this dict should correspond to column names, and the values should be lists of strings corresponding to the specific display order desired.
#
# labels: dict with str keys and str values (default `{}`) By default, column names are used in the figure for axis titles, legend entries and hovers. This parameter allows this to be overridden. The keys of this dict should correspond to column names, and the values should correspond to the desired label to be displayed.
#
# orientation: str, one of `'h'` for horizontal or `'v'` for vertical. (default `'v'` if `x` and `y` are provided and both continous or both categorical,  otherwise `'v'`(`'h'`) if `x`(`y`) is categorical and `y`(`x`) is continuous,  otherwise `'v'`(`'h'`) if only `x`(`y`) is provided)
#
# color_discrete_sequence: list of str Strings should define valid CSS-colors. When `color` is set and the values in the corresponding column are not numeric, values in that column are assigned colors by cycling through `color_discrete_sequence` in the order described in `category_orders`, unless the value of `color` is a key in `color_discrete_map`. Various useful color sequences are available in the `plotly.express.colors` submodules, specifically `plotly.express.colors.qualitative`.
#
# color_discrete_map: dict with str keys and str values (default `{}`) String values should define valid CSS-colors Used to override `color_discrete_sequence` to assign a specific colors to marks corresponding with specific values. Keys in `color_discrete_map` should be values in the column denoted by `color`. Alternatively, if the values of `color` are valid colors, the string `'identity'` may be passed to cause them to be used directly.
#
# color_continuous_scale: list of str Strings should define valid CSS-colors This list is used to build a continuous color scale when the column denoted by `color` contains numeric data. Various useful color scales are available in the `plotly.express.colors` submodules, specifically `plotly.express.colors.sequential`, `plotly.express.colors.diverging` and `plotly.express.colors.cyclical`.
#
# range_color: list of two numbers If provided, overrides auto-scaling on the continuous color scale.
#
# color_continuous_midpoint: number (default `None`) If set, computes the bounds of the continuous color scale to have the desired midpoint. Setting this value is recommended when using `plotly.express.colors.diverging` color scales as the inputs to `color_continuous_scale`.
#
# symbol_sequence: list of str Strings should define valid plotly.js symbols. When `symbol` is set, values in that column are assigned symbols by cycling through `symbol_sequence` in the order described in `category_orders`, unless the value of `symbol` is a key in `symbol_map`.
#
# symbol_map: dict with str keys and str values (default `{}`) String values should define plotly.js symbols Used to override `symbol_sequence` to assign a specific symbols to marks corresponding with specific values. Keys in `symbol_map` should be values in the column denoted by `symbol`. Alternatively, if the values of `symbol` are valid symbol names, the string `'identity'` may be passed to cause them to be used directly.
#
# opacity: float Value between 0 and 1. Sets the opacity for markers.
#
# size_max: int (default `20`) Set the maximum mark size when using `size`.
#
# marginal_x: str One of `'rug'`, `'box'`, `'violin'`, or `'histogram'`. If set, a horizontal subplot is drawn above the main plot, visualizing the x-distribution.
#
# marginal_y: str One of `'rug'`, `'box'`, `'violin'`, or `'histogram'`. If set, a vertical subplot is drawn to the right of the main plot, visualizing the y-distribution.
#
# trendline: str One of `'ols'`, `'lowess'`, `'rolling'`, `'expanding'` or `'ewm'`. If `'ols'`, an Ordinary Least Squares regression line will be drawn for each discrete-color/symbol group. If `'lowess`', a Locally Weighted Scatterplot Smoothing line will be drawn for each discrete-color/symbol group. If `'rolling`', a Rolling (e.g. rolling average, rolling median) line will be drawn for each discrete-color/symbol group. If `'expanding`', an Expanding (e.g. expanding average, expanding sum) line will be drawn for each discrete-color/symbol group. If `'ewm`', an Exponentially Weighted Moment (e.g. exponentially-weighted moving average) line will be drawn for each discrete-color/symbol group. See the docstrings for the functions in `plotly.express.trendline_functions` for more details on these functions and how to configure them with the `trendline_options` argument.
#
# trendline_options: dict Options passed as the first argument to the function from `plotly.express.trendline_functions`  named in the `trendline` argument.
#
# trendline_color_override: str Valid CSS color. If provided, and if `trendline` is set, all trendlines will be drawn in this color rather than in the same color as the traces from which they draw their inputs.
#
# trendline_scope: str (one of `'trace'` or `'overall'`, default `'trace'`) If `'trace'`, then one trendline is drawn per trace (i.e. per color, symbol, facet, animation frame etc) and if `'overall'` then one trendline is computed for the entire dataset, and replicated across all facets.
#
# log_x: boolean (default `False`) If `True`, the x-axis is log-scaled in cartesian coordinates.
#
# log_y: boolean (default `False`) If `True`, the y-axis is log-scaled in cartesian coordinates.
#
# range_x: list of two numbers If provided, overrides auto-scaling on the x-axis in cartesian coordinates.
#
# range_y: list of two numbers If provided, overrides auto-scaling on the y-axis in cartesian coordinates.
#
# render_mode: str One of `'auto'`, `'svg'` or `'webgl'`, default `'auto'` Controls the browser API used to draw marks. `'svg`' is appropriate for figures of less than 1000 data points, and will allow for fully-vectorized output. `'webgl'` is likely necessary for acceptable performance above 1000 points but rasterizes part of the output.  `'auto'` uses heuristics to choose the mode.
#
# title: str The figure title.
#
# template: str or dict or plotly.graph_objects.layout.Template instance The figure template name (must be a key in plotly.io.templates) or definition.
#
# width: int (default `None`) The figure width in pixels.
#
# height: int (default `None`) The figure height in pixels.
#
#
#
# Returns
#
# ------- plotly.graph_objects.Figure
